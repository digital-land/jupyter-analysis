# %% [markdown]
# # Title
# **Author**:  Greg Slater <br>
# **Date**:  24th September 2024 <br>
# **Dataset Scope**: `dataset` <br>
# **Report Type**: Ad-hoc analysis <br>
#
# ## Purpose

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import urllib
# from sqlite_query_functions import DatasetSqlite
from datetime import datetime

td = datetime.today().strftime('%Y-%m-%d')

pd.set_option("display.max_rows", 100)

data_dir = "data/"
os.makedirs(data_dir, exist_ok=True)

# %%
def get_pdp_dataset(dataset, geometry_field = "geometry", crs_out=4326, underscore_cols=True):

    df = pd.read_csv(f"https://files.planning.data.gov.uk/dataset/{dataset}.csv", dtype = "str")
    df.columns = [x.replace("-", "_") for x in df.columns]

    df_valid_geom = df[df[geometry_field].notnull()].copy()

    # load geometry and create GDF
    df_valid_geom[geometry_field] = df_valid_geom[geometry_field].apply(shapely.wkt.loads)
    gdf = gpd.GeoDataFrame(df_valid_geom, geometry = geometry_field)

    # Transform to ESPG:27700 for more interpretable area units
    gdf.set_crs(epsg=4326, inplace=True)
    gdf.to_crs(epsg=crs_out, inplace=True)

    return gdf

# %% [markdown]
# ## Data Import

# %%
seed_dupe_df = pd.read_csv("data/DuplicateEntityNames2.csv", dtype = str)

seed_dupe_df[["entity_max", "entity_min"]]= seed_dupe_df[["entity_max", "entity_min"]].astype(str)
seed_dupe_df["entity_join"] = seed_dupe_df.apply(lambda x: '-'.join(sorted(x[["entity_min", "entity_max"]])), axis=1)

print(len(seed_dupe_df))
# seed_dupe_df.head()

issues_df = pd.read_csv("data/issues_all.csv", dtype = "str")
print(len(issues_df))
issues_df.head()
# Out:
# 47
# 2347
#          entity_join  entity_1 entry_date_1                          name_1  \
# 0  44000007-44000009  44000009   2004-06-01                   Childwickbury
# 1  44000017-44000770  44000770   2023-07-22                 Leominster Town
# 2  44000042-44000043  44000043   2023-07-22                Butterworth Hall
# 3  44000050-44003132  44003132   2023-07-22  Worcester and Birmingham Canal
# 4  44000105-44005296  44005296   2023-07-22                           Lewes
#
#   organisation_entity_1 reference_1                  organisation_name_1  \
# 0                   278         CA3  St Albans City and District Council
# 1                    16        2499                     Historic England
# 2                    16        7716                     Historic England
# 3                    16         449                     Historic England
# 4                    16        3207                     Historic England
#
#    entity_2 entry_date_2                                  name_2  ...  \
# 0  44000007   2004-06-01                               Harpenden  ...
# 1  44000017   2023-07-22                Leominster River Meadows  ...
# 2  44000042   2023-07-22  Butterworth Hall (Municipal Buildings)  ...
# 3  44000050   2023-07-22          Worcester and Birmingham Canal  ...
# 4  44000105   2023-07-22                 Lewes (Malling Deanery)  ...
#
#                    organisation_name_2    pct_min_intersection date_match  \
# 0  St Albans City and District Council  1.1508995698706748e-06       True
# 1                     Historic England  1.1282780843611863e-05       True
# 2                     Historic England                     0.0       True
# 3                     Historic England  1.6264203793924812e-05       True
# 4                     Historic England   0.0011782286279958154       True
#
#   entity_old   intersection_type                              issue_type  \
# 0      False  tiny edge - ignore               Within organisation - LPA
# 1      False  tiny edge - ignore  Within organisation - Historic England
# 2      False  tiny edge - ignore  Within organisation - Historic England
# 3      False  tiny edge - ignore  Within organisation - Historic England
# 4      False  tiny edge - ignore  Within organisation - Historic England
#
#    action priority hint multiple_issues
# 0  ignore      NaN  NaN           False
# 1  ignore      NaN  NaN           False
# 2  ignore      NaN  NaN           False
# 3  ignore      NaN  NaN           False
# 4  ignore      NaN  NaN           False
#
# [5 rows x 22 columns]

# %%
issues_df.dtypes
# Out:
# entity_join              object
# entity_1                 object
# entry_date_1             object
# name_1                   object
# organisation_entity_1    object
# reference_1              object
# organisation_name_1      object
# entity_2                 object
# entry_date_2             object
# name_2                   object
# organisation_entity_2    object
# reference_2              object
# organisation_name_2      object
# pct_min_intersection     object
# date_match               object
# entity_old               object
# intersection_type        object
# issue_type               object
# action                   object
# priority                 object
# hint                     object
# multiple_issues          object
# dtype: object

# %%
seed_dupe_df = seed_dupe_df.merge(
    issues_df[["entity_join", "entity_1", "organisation_entity_1", "organisation_name_1", "pct_min_intersection", "intersection_type", "issue_type", "action", "priority", "multiple_issues"]],
    how = "left",
    on = "entity_join"
)

seed_dupe_df.to_csv("seeding_dupes_flagged_w_e1.csv", index=False)

# %%
print(len(issues_df[issues_df["entity_join"].isin(seed_dupe_df["entity_join"])]))
# Out:
# 24

# %%
seed_dupe_df
# Out:
#                                         lpa               entity_name  \
# 0   Calderdale Metropolitan Borough Council                    Elland
# 1   Calderdale Metropolitan Borough Council             Hebden Bridge
# 2   Calderdale Metropolitan Borough Council                 Todmorden
# 3                     Carlisle City Council               Botchergate
# 4                     Carlisle City Council      Carlisle City Centre
# 5                          Cornwall Council                   Helston
# 6              Cumberland Unitary Authority               Botchergate
# 7              Cumberland Unitary Authority      Carlisle City Centre
# 8                      East Suffolk Council                 Aldeburgh
# 9                      East Suffolk Council                   Beccles
# 10                     East Suffolk Council                 Bramfield
# 11                     East Suffolk Council                   Dunwich
# 12                     East Suffolk Council                Earl Soham
# 13                     East Suffolk Council             Great Glemham
# 14                     East Suffolk Council              Grundisburgh
# 15                     East Suffolk Council                   Leiston
# 16                     East Suffolk Council           North Lowestoft
# 17                     East Suffolk Council              Oulton Broad
# 18                     East Suffolk Council                Pettistree
# 19                Guildford Borough Council          Holmbury St Mary
# 20                  Maldon District Council                Goldhanger
# 21                  Maldon District Council           Heybridge Basin
# 22                  Maldon District Council                  Langford
# 23                  Maldon District Council                  Purleigh
# 24                  Maldon District Council              Southminster
# 25                  Maldon District Council                Tillingham
# 26                  Maldon District Council                Tollesbury
# 27                  Maldon District Council         Tolleshunt D'arcy
# 28             Mole Valley District Council     Conservation_Area.TAB
# 29    Peak District National Park Authority                    Alport
# 30    Peak District National Park Authority                     Holme
# 31    Peak District National Park Authority                Tintwistle
