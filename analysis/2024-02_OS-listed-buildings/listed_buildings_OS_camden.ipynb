# %%
from osdatahub import FeaturesAPI, Extent, NGD
import geojson
import pandas as pd
import geopandas as gpd
import shapely.wkt
import shapely.geometry
import os

from key import ngd_key

pd.set_option("display.max_rows", 100)

data_dir = "../data/geo_analysis/os_licensing/"
os.makedirs(data_dir, exist_ok=True)

# %%
def nrow(df):
    return print(f"No. of records in df: {len(df):,}")

# %% [markdown]
# ## Data import

# %%
# LPA boundary data from planning.data.gov

LAD_boundary_df = pd.read_csv("https://files.planning.data.gov.uk/dataset/local-authority-district.csv", 
                                  usecols = ["reference", "name", "geometry"])

# LAD_boundary_df.columns = ["geometry", "name", "LPACD"]


# load geometry and create GDF
LAD_boundary_df['geometry'] = LAD_boundary_df['geometry'].apply(shapely.wkt.loads)
LAD_boundary_gdf = gpd.GeoDataFrame(LAD_boundary_df, geometry='geometry')

# Transform to ESPG:27700 for more interpretable area units
LAD_boundary_gdf.set_crs(epsg=4326, inplace=True)
LAD_boundary_gdf.to_crs(epsg=27700, inplace=True)

nrow(LAD_boundary_gdf)
LAD_boundary_gdf.head()
# Out:
# No. of records in df: 344
#                                             geometry                  name  \
# 0  MULTIPOLYGON (((450154.627 525938.188, 450164....            Hartlepool
# 1  MULTIPOLYGON (((446854.689 517192.726, 446858....         Middlesbrough
# 2  MULTIPOLYGON (((451747.383 520561.094, 451698....  Redcar and Cleveland
# 3  MULTIPOLYGON (((447177.708 517811.773, 447198....      Stockton-on-Tees
# 4  MULTIPOLYGON (((423496.594 524724.326, 423475....            Darlington
#
#    reference
# 0  E06000001
# 1  E06000002
# 2  E06000003
# 3  E06000004
# 4  E06000005

# %%
# get camden listed building data direct from endpoint
cmd_df = pd.read_csv("https://opendata.camden.gov.uk/api/views/uu3n-zgbj/rows.csv?accessType=DOWNLOAD")

# load geometry and create GDF
cmd_df['geometry'] = cmd_df['geometry'].apply(shapely.wkt.loads)
cmd_gdf = gpd.GeoDataFrame(cmd_df[["reference", "geometry"]], geometry='geometry')

cmd_gdf["geogcd"] = "E09000007"

# Transform to ESPG:27700 for more interpretable area units
cmd_gdf.set_crs(epsg=4326, inplace=True)
cmd_gdf.to_crs(epsg=27700, inplace=True)

nrow(cmd_gdf)
cmd_gdf.head()
# Out:
# No. of records in df: 1,961
#   reference                                           geometry     geogcd
# 0    LB1859  POLYGON ((529794.083 183544.904, 529791.773 18...  E09000007
# 1    LB1481  POLYGON ((525383.827 186281.856, 525383.774 18...  E09000007
# 2    LB1872  POLYGON ((526706.983 184142.479, 526706.278 18...  E09000007
# 3    LB1531  POLYGON ((529534.796 181777.495, 529525.359 18...  E09000007
# 4    LB1532  POLYGON ((529598.623 181849.781, 529599.345 18...  E09000007

# %%
nrow(cmd_gdf)
# Out:
# No. of records in df: 1,961

# %% [markdown]
# ## API test

# %%
# create a simplified geometry of the LAD polygon to use in API query
# this should mean downloading less unused data than just using a bounding box
# geometry needs to be simplified so query doesn't exceed max length, and buffered too so as to not clip out areas

area_code = "E09000007"
buffer_dist = 250
simp_tolerance = 250

area_geom = LAD_boundary_gdf[LAD_boundary_gdf["reference"] == area_code]["geometry"]
area_geom_simple = area_geom.simplify(simp_tolerance).buffer(buffer_dist).to_crs(4326).explode()
poly_str = shapely.wkt.dumps(area_geom_simple.values[0], rounding_precision=2)

len(poly_str)
# Out:
# /var/folders/0p/chrk2fd55l76zwfn62dphwvw0000gn/T/ipykernel_61324/2673653809.py:10: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   area_geom_simple = area_geom.simplify(simp_tolerance).buffer(buffer_dist).to_crs(4326).explode()
# 1947

# %%
coords = ((529000,181000), (530000,181000), (530000,182000), (529000,182000), (529000,181000))
bbox_poly = shapely.geometry.Polygon(coords)

map_lad = area_geom.explore(
    color = "blue"
)

area_geom_simple.explore(
    m = map_lad,
    color = "red"
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_460194f80dd262fa2ac72296ec5b4e05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_460194f80dd262fa2ac72296ec5b4e05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_460194f80dd262fa2ac72296ec5b4e05 = L.map(
#                 &quot;map_460194f80dd262fa2ac72296ec5b4e05&quot;,
#                 {
#                     center: [51.5428175, -0.1593995000000003],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_460194f80dd262fa2ac72296ec5b4e05);
#
#
#
#
#
#             var tile_layer_071daaec263b5c278b4f1ba04200c2bf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_460194f80dd262fa2ac72296ec5b4e05);
#
#
#             map_460194f80dd262fa2ac72296ec5b4e05.fitBounds(
#                 [[51.51265399999999, -0.2134769999999996], [51.572981, -0.10532200000000103]],
#                 {}
#             );
#
#
#         function geo_json_0df0a9c945b12803ced03135dd5df0e2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0df0a9c945b12803ced03135dd5df0e2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0df0a9c945b12803ced03135dd5df0e2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0df0a9c945b12803ced03135dd5df0e2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0df0a9c945b12803ced03135dd5df0e2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0df0a9c945b12803ced03135dd5df0e2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0df0a9c945b12803ced03135dd5df0e2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0df0a9c945b12803ced03135dd5df0e2 = L.geoJson(null, {
#                 onEachFeature: geo_json_0df0a9c945b12803ced03135dd5df0e2_onEachFeature,
#
#                 style: geo_json_0df0a9c945b12803ced03135dd5df0e2_styler,
#                 pointToLayer: geo_json_0df0a9c945b12803ced03135dd5df0e2_pointToLayer
#         });
#
#         function geo_json_0df0a9c945b12803ced03135dd5df0e2_add (data) {
#             geo_json_0df0a9c945b12803ced03135dd5df0e2
#                 .addData(data)
#                 .addTo(map_460194f80dd262fa2ac72296ec5b4e05);
#         }
#             geo_json_0df0a9c945b12803ced03135dd5df0e2_add({&quot;bbox&quot;: [-0.21347699

# %%
collection = "bld-fts-buildingpart-1"
ngd = NGD(ngd_key, collection)


cql = f"INTERSECTS(geometry, {poly_str})"

results = ngd.query(
    max_results=10, 
    cql_filter = cql,
    crs = 27700, 
    offset = 0
)

test_gdf = gpd.GeoDataFrame.from_features(results["features"])
test_gdf.set_crs(epsg=27700, inplace=True)

nrow(test_gdf)
# Out:
# No. of records in df: 10

# %%
test_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa25c09a39e6b1de1f83012c91bb6fbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa25c09a39e6b1de1f83012c91bb6fbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa25c09a39e6b1de1f83012c91bb6fbc = L.map(
#                 &quot;map_aa25c09a39e6b1de1f83012c91bb6fbc&quot;,
#                 {
#                     center: [51.539254899705455, -0.16248451595461627],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aa25c09a39e6b1de1f83012c91bb6fbc);
#
#
#
#
#
#             var tile_layer_aa5a351f3a8e24450178277216d9d6fe = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa25c09a39e6b1de1f83012c91bb6fbc);
#
#
#             map_aa25c09a39e6b1de1f83012c91bb6fbc.fitBounds(
#                 [[51.51029877544337, -0.2162087459918479], [51.56821102396755, -0.10876028591738467]],
#                 {}
#             );
#
#
#         function geo_json_8b183653bbdcf7084daea5fb85155e24_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8b183653bbdcf7084daea5fb85155e24_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8b183653bbdcf7084daea5fb85155e24_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8b183653bbdcf7084daea5fb85155e24_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8b183653bbdcf7084daea5fb85155e24_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8b183653bbdcf7084daea5fb85155e24.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8b183653bbdcf7084daea5fb85155e24_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8b183653bbdcf7084daea5fb85155e24 = L.geoJson(null, {
#                 onEachFeature: geo_json_8b183653bbdcf7084daea5fb85155e24_onEachFeature,
#
#                 style: geo_json_8b183653bbdcf7084daea5fb85155e24_styler,
#                 pointToLayer: geo_json_8b183653bbdcf7084daea5fb85155e24_pointToLayer
#         });
#
#         function geo_json_8b183653bbdcf7084daea5fb85155e24_add (data) {
#             geo_json_8b183653bbdcf7084daea5fb85155e24
#                 .addData(data)
#                 .addTo(map_aa25c09a39e6b1de1f83012c91bb6fbc);
#         }
#             geo_json_8b183653bbdcf7084daea5fb85155e24_add({&quot;bbox&quot;: [-0.2162087459918479, 51.51029877544337, -0.10876028591738467, 51.56821102396755], &quot;features&quot;: [{&quot;bbox&quot;: [-0.10889219810195812, 51.522902038527995, -0.10876028591738467, 51.52299272794629], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.10878539631923358, 51.52291553486053], [-0.10879820642803024, 51.52293687431965], [-0.10876028591738467, 51.5229475039507], [-0.10877643065844374, 51.52299272794629], [-0.10889219810195812, 51.52298200428934], [-0.10884073402806438, 51.522902038527995], [-0.10878539631923358, 51.52291553486053]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quo

# %% [markdown]
# ## Full API query

# %%
# API details
collection = "bld-fts-buildingpart-1"
ngd = NGD(ngd_key, collection)

# bounding box query
cql = f"INTERSECTS(geometry, {poly_str})"
# cql = f"INTERSECTS(geometry, {shapely.wkt.dumps(bbox_gdf.to_crs(27700).buffer(200)[0], rounding_precision=4)})"

fields = ["geometry", "osid", "versiondate"]

# controls
limit = 80000
interval = 100
fail_limit = 10

# data storage & counter
api_results = []
fail_counter = 0

for count, offset in enumerate(range(0, limit, interval)):

    if fail_counter > fail_limit:
        break
    
    print(f"attempt number {count}")
    try:
        results = ngd.query(cql_filter = cql, crs = 27700, max_results = interval, offset = offset)
        print("query success")

        results_gdf = gpd.GeoDataFrame.from_features(results["features"])
        results_gdf.set_crs(epsg=27700, inplace=True)

        api_results.append(results_gdf[fields])

    except:
        print("query fail")
        fail_counter += 1


    # api_results.append(results_gdf)

    # if there isn't a next page in the response then break
    if not any(d["rel"] == "next" for d in results["links"]):
        break
        

os_gdf = pd.concat(api_results)
nrow(os_gdf)
# Out:
# attempt number 0
# query success
# attempt number 1
# query success
# attempt number 2
# query success
# attempt number 3
# query success
# attempt number 4
# query success
# attempt number 5
# query success
# attempt number 6
# query success
# attempt number 7
# query success
# attempt number 8
# query success
# attempt number 9
# query success
# attempt number 10
# query success
# attempt number 11
# query success
# attempt number 12
# query success
# attempt number 13
# query success
# attempt number 14
# query success
# attempt number 15
# query success
# attempt number 16
# query success
# attempt number 17
# query success
# attempt number 18
# query success
# attempt number 19
# query success
# attempt number 20
# query success
# attempt number 21
# query success
# attempt number 22
# query success
# attempt number 23
# query success
# attempt number 24
# query success
# attempt number 25
# query success
# attempt number 26
# query success
# attempt number 27
# query success
# attempt number 28
# query success
# attempt number 29
# query success
# attempt number 30
# query success
# attempt number 31
# query success
# attempt number 32
# query success
# attempt number 33
# query success
# attempt number 34
# query success
# attempt number 35
# query success
# attempt number 36
# query success
# attempt number 37
# query success
# attempt number 38
# query success
# attempt number 39
# query success
# attempt number 40
# query success
# attempt number 41
# query success
# attempt number 42
# query success
# attempt number 43
# query success
# attempt number 44
# query success
# attempt number 45
# query success
# attempt number 46
# query success
# attempt number 47
# query success
# attempt number 48
# query success
# attempt number 49
# query success
# attempt number 50
# query success
# attempt number 51
# query success
# attempt number 52
# query success
# attempt number 53
# query success
# attempt number 54
# query success
# attempt number 55
# query success
# attempt number 56
# query success
# attempt number 57
# query success
# attempt number 58
# query success
# attempt number 59
# query success
# attempt number 60
# query success
# attempt number 61
# query success
# attempt number 62
# query success
# attempt number 63
# query success
# attempt number 64
# query success
# attempt number 65
# query success
# attempt number 66
# query success
# attempt number 67
# query success
# attempt number 68
# query success
# attempt number 69
# query success
# attempt number 70
# query success
# attempt number 71
# query success
# attempt number 72
# query success
# attempt number 73
# query success
# attempt number 74
# query success
# attempt number 75
# query success
# attempt number 76
# query success
# attempt number 77
# query success
# attempt number 78
# query success
# attempt number 79
# query success
# attempt number 80
# query success
# attempt number 81
# query success
# attempt number 82
# query success
# attempt number 83
# query success
# attempt number 84
# query success
# attempt number 85
# query success
# attempt number 86
# query success
# attempt number 87
# query success
# attempt number 88
# query success
# attempt number 89
# query success
# attempt number 90
# query success
# attempt number 91
# query success
# attempt number 92
# query success
# attempt number 93
# query success
# attempt number 94
# query success
# attempt number 95
# query success
# attempt number 96
# query success
# attempt number 97
# query success
# attempt number 98
# query success
# attempt number 99
# query success
# attempt number 100
# query success
# attempt number 101
# query success
# attempt number 102
# query success
# attempt number 103
# query success
# attempt number 104
# query success
# attempt number 105
# query success
# attempt number 106
# query success
# attempt number 107
# query success
# attempt number 108
# query success
# attempt number 109
# query success
# attempt number 110
# query success
# attempt number 111
# query success
# attempt number 112
# query success
# attempt number 113
# query success
# attempt number 114
# query success
# attempt number 115
# query success
# attempt number 116
# query success
# attempt number 117
# query success
# attempt number 118
# query success
# attempt number 119
# query success
# attempt number 120
# query success
# attempt number 121
# query success
# attempt number 122
# query success
# attempt number 123
# query success
# attempt number 124
# query success
# attempt number 125
# query success
# attempt number 126
# query success
# attempt number 127
# query success
# attempt number 128
# query success
# attempt number 129
# query success
# attempt number 130
# query success
# attempt number 131
# query success
# attempt number 132
# query success
# attempt number 133
# query success
# attempt number 134
# query success
# attempt number 135
# query success
# attempt number 136
# query success
# attempt number 137
# query success
# attempt number 138
# query success
# attempt number 139
# query success
# attempt number 140
# query success
# attempt number 141
# query success
# attempt number 142
# query success
# attempt number 143
# query success
# attempt number 144
# query success
# attempt number 145
# query success
# attempt number 146
# query success
# attempt number 147
# query success
# attempt number 148
# query success
# attempt number 149
# query success
# attempt number 150
# query success
# attempt number 151
# query success
# attempt number 152
# query success
# attempt number 153
# query success
# attempt number 154
# query success
# attempt number 155
# query success
# attempt number 156
# query success
# attempt number 157
# query success
# attempt number 158
# query success
# attempt number 159
# query success
# attempt number 160
# query success
# attempt number 161
# query success
# attempt number 162
# query success
# attempt number 163
# query success
# attempt number 164
# query success
# attempt number 165
# query success
# attempt number 166
# query success
# attempt number 167
# query success
# attempt number 168
# query success
# attempt number 169
# query success
# attempt number 170
# query success
# attempt number 171
# query success
# attempt number 172
# query success
# attempt number 173
# query success
# attempt number 174
# query success
# attempt number 175
# query success
# attempt number 176
# query success
# attempt number 177
# query success
# attempt number 178
# query success
# attempt number 179
# query success
# attempt number 180
# query success
# attempt number 181
# query success
# attempt number 182
# query success
# attempt number 183
# query success
# attempt number 184
# query success
# attempt number 185
# query success
# attempt number 186
# query success
# attempt number 187
# query success
# attempt number 188
# query success
# attempt number 189
# query success
# attempt number 190
# query success
# attempt number 191
# query success
# attempt number 192
# query success
# attempt number 193
# query success
# attempt number 194
# query success
# attempt number 195
# query success
# attempt number 196
# query success
# attempt number 197
# query success
# attempt number 198
# query success
# attempt number 199
# query success
# attempt number 200
# query success
# attempt number 201
# query success
# attempt number 202
# query success
# attempt number 203
# query success
# attempt number 204
# query success
# attempt number 205
# query success
# attempt number 206
# query success
# attempt number 207
# query success
# attempt number 208
# query success
# attempt number 209
# query success
# attempt number 210
# query success
# attempt number 211
# query success
# attempt number 212
# query success
# attempt number 213
# query success
# attempt number 214
# query success
# attempt number 215
# query success
# attempt number 216
# query success
# attempt number 217
# query success
# attempt number 218
# query success
# attempt number 219
# query success
# attempt number 220
# query success
# attempt number 221
# query success
# attempt number 222
# query success
# attempt number 223
# query success
# attempt number 224
# query success
# attempt number 225
# query success
# attempt number 226
# query success
# attempt number 227
# query success
# attempt number 228
# query success
# attempt number 229
# query success
# attempt number 230
# query success
# attempt number 231
# query success
# attempt number 232
# query success
# attempt number 233
# query success
# attempt number 234
# query success
# attempt number 235
# query success
# attempt number 236
# query success
# attempt number 237
# query success
# attempt number 238
# query success
# attempt number 239
# query success
# attempt number 240
# query success
# attempt number 241
# query success
# attempt number 242
# query success
# attempt number 243
# query success
# attempt number 244
# query success
# attempt number 245
# query success
# attempt number 246
# query success
# attempt number 247
# query success
# attempt number 248
# query success
# attempt number 249
# query success
# attempt number 250
# query success
# attempt number 251
# query success
# attempt number 252
# query success
# attempt number 253
# query success
# attempt number 254
# query success
# attempt number 255
# query success
# attempt number 256
# query success
# attempt number 257
# query success
# attempt number 258
# query success
# attempt number 259
# query success
# attempt number 260
# query success
# attempt number 261
# query success
# attempt number 262
# query success
# attempt number 263
# query success
# attempt number 264
# query success
# attempt number 265
# query success
# attempt number 266
# query success
# attempt number 267
# query success
# attempt number 268
# query success
# attempt number 269
# query success
# attempt number 270
# query success
# attempt number 271
# query success
# attempt number 272
# query success
# attempt number 273
# query success
# attempt number 274
# query success
# attempt number 275
# query success
# attempt number 276
# query success
# attempt number 277
# query success
# attempt number 278
# query success
# attempt number 279
# query success
# attempt number 280
# query success
# attempt number 281
# query success
# attempt number 282
# query success
# attempt number 283
# query success
# attempt number 284
# query success
# attempt number 285
# query success
# attempt number 286
# query success
# attempt number 287
# query success
# attempt number 288
# query success
# attempt number 289
# query success
# attempt number 290
# query success
# attempt number 291
# query success
# attempt number 292
# query success
# attempt number 293
# query success
# attempt number 294
# query success
# attempt number 295
# query success
# attempt number 296
# query success
# attempt number 297
# query success
# attempt number 298
# query success
# attempt number 299
# query success
# attempt number 300
# query success
# attempt number 301
# query success
# attempt number 302
# query success
# attempt number 303
# query success
# attempt number 304
# query success
# attempt number 305
# query success
# attempt number 306
# query success
# attempt number 307
# query success
# attempt number 308
# query success
# attempt number 309
# query success
# attempt number 310
# query success
# attempt number 311
# query success
# attempt number 312
# query success
# attempt number 313
# query success
# attempt number 314
# query success
# attempt number 315
# query success
# attempt number 316
# query success
# attempt number 317
# query success
# attempt number 318
# query success
# attempt number 319
# query success
# attempt number 320
# query success
# attempt number 321
# query success
# attempt number 322
# query success
# attempt number 323
# query success
# attempt number 324
# query success
# attempt number 325
# query success
# attempt number 326
# query success
# attempt number 327
# query success
# attempt number 328
# query success
# attempt number 329
# query success
# attempt number 330
# query success
# attempt number 331
# query success
# attempt number 332
# query success
# attempt number 333
# query success
# attempt number 334
# query success
# attempt number 335
# query success
# attempt number 336
# query success
# attempt number 337
# query success
# attempt number 338
# query success
# attempt number 339
# query success
# attempt number 340
# query success
# attempt number 341
# query success
# attempt number 342
# query success
# attempt number 343
# query success
# attempt number 344
# query success
# attempt number 345
# query success
# attempt number 346
# query success
# attempt number 347
# query success
# attempt number 348
# query success
# attempt number 349
# query success
# attempt number 350
# query success
# attempt number 351
# query success
# attempt number 352
# query success
# attempt number 353
# query success
# attempt number 354
# query success
# attempt number 355
# query success
# attempt number 356
# query success
# attempt number 357
# query success
# attempt number 358
# query success
# attempt number 359
# query success
# attempt number 360
# query success
# attempt number 361
# query success
# attempt number 362
# query success
# attempt number 363
# query success
# attempt number 364
# query success
# attempt number 365
# query success
# attempt number 366
# query success
# attempt number 367
# query success
# attempt number 368
# query success
# attempt number 369
# query success
# attempt number 370
# query success
# attempt number 371
# query success
# attempt number 372
# query success
# attempt number 373
# query success
# attempt number 374
# query success
# attempt number 375
# query success
# attempt number 376
# query success
# attempt number 377
# query success
# attempt number 378
# query success
# attempt number 379
# query success
# attempt number 380
# query success
# attempt number 381
# query success
# attempt number 382
# query success
# attempt number 383
# query success
# attempt number 384
# query success
# attempt number 385
# query success
# attempt number 386
# query success
# attempt number 387
# query success
# attempt number 388
# query success
# attempt number 389
# query success
# attempt number 390
# query success
# attempt number 391
# query success
# attempt number 392
# query success
# attempt number 393
# query success
# attempt number 394
# query success
# attempt number 395
# query success
# attempt number 396
# query success
# attempt number 397
# query success
# attempt number 398
# query success
# attempt number 399
# query success
# attempt number 400
# query success
# attempt number 401
# query success
# attempt number 402
# query success
# attempt number 403
# query success
# attempt number 404
# query success
# attempt number 405
# query success
# attempt number 406
# query success
# attempt number 407
# query success
# attempt number 408
# query success
# attempt number 409
# query success
# attempt number 410
# query success
# attempt number 411
# query success
# attempt number 412
# query success
# attempt number 413
# query success
# attempt number 414
# query success
# attempt number 415
# query success
# attempt number 416
# query success
# attempt number 417
# query success
# attempt number 418
# query success
# attempt number 419
# query success
# attempt number 420
# query success
# attempt number 421
# query success
# attempt number 422
# query success
# attempt number 423
# query success
# attempt number 424
# query success
# attempt number 425
# query success
# attempt number 426
# query success
# attempt number 427
# query success
# attempt number 428
# query success
# attempt number 429
# query success
# attempt number 430
# query success
# attempt number 431
# query success
# attempt number 432
# query success
# attempt number 433
# query success
# attempt number 434
# query success
# attempt number 435
# query success
# attempt number 436
# query success
# attempt number 437
# query success
# attempt number 438
# query success
# attempt number 439
# query success
# attempt number 440
# query success
# attempt number 441
# query success
# attempt number 442
# query success
# attempt number 443
# query success
# attempt number 444
# query success
# attempt number 445
# query success
# attempt number 446
# query success
# attempt number 447
# query success
# attempt number 448
# query success
# attempt number 449
# query success
# attempt number 450
# query success
# attempt number 451
# query success
# attempt number 452
# query success
# attempt number 453
# query success
# attempt number 454
# query success
# attempt number 455
# query success
# attempt number 456
# query success
# attempt number 457
# query success
# attempt number 458
# query success
# attempt number 459
# query success
# attempt number 460
# query success
# attempt number 461
# query success
# attempt number 462
# query success
# attempt number 463
# query success
# attempt number 464
# query success
# attempt number 465
# query success
# attempt number 466
# query success
# attempt number 467
# query success
# attempt number 468
# query success
# attempt number 469
# query success
# attempt number 470
# query success
# attempt number 471
# query success
# attempt number 472
# query success
# attempt number 473
# query success
# attempt number 474
# query success
# attempt number 475
# query success
# attempt number 476
# query success
# attempt number 477
# query success
# attempt number 478
# query success
# attempt number 479
# query success
# attempt number 480
# query success
# attempt number 481
# query success
# attempt number 482
# query success
# attempt number 483
# query success
# attempt number 484
# query success
# attempt number 485
# query success
# attempt number 486
# query success
# attempt number 487
# query success
# attempt number 488
# query success
# attempt number 489
# query success
# attempt number 490
# query success
# attempt number 491
# query success
# attempt number 492
# query success
# attempt number 493
# query success
# attempt number 494
# query success
# attempt number 495
# query success
# attempt number 496
# query success
# attempt number 497
# query success
# attempt number 498
# query success
# attempt number 499
# query success
# attempt number 500
# query success
# attempt number 501
# query success
# attempt number 502
# query success
# attempt number 503
# query success
# attempt number 504
# query success
# attempt number 505
# query success
# attempt number 506
# query success
# attempt number 507
# query success
# attempt number 508
# query success
# attempt number 509
# query success
# attempt number 510
# query success
# attempt number 511
# query success
# attempt number 512
# query success
# attempt number 513
# query success
# attempt number 514
# query success
# attempt number 515
# query success
# attempt number 516
# query success
# attempt number 517
# query success
# attempt number 518
# query success
# attempt number 519
# query success
# attempt number 520
# query success
# attempt number 521
# query success
# attempt number 522
# query success
# attempt number 523
# query success
# attempt number 524
# query success
# attempt number 525
# query success
# attempt number 526
# query success
# attempt number 527
# query success
# attempt number 528
# query success
# attempt number 529
# query success
# attempt number 530
# query success
# attempt number 531
# query success
# attempt number 532
# query success
# attempt number 533
# query success
# attempt number 534
# query success
# attempt number 535
# query success
# attempt number 536
# query success
# attempt number 537
# query success
# attempt number 538
# query success
# attempt number 539
# query success
# attempt number 540
# query success
# attempt number 541
# query success
# attempt number 542
# query success
# attempt number 543
# query success
# attempt number 544
# query success
# attempt number 545
# query success
# attempt number 546
# query success
# attempt number 547
# query success
# attempt number 548
# query success
# attempt number 549
# query success
# attempt number 550
# query success
# attempt number 551
# query success
# attempt number 552
# query success
# attempt number 553
# query success
# attempt number 554
# query success
# attempt number 555
# query success
# attempt number 556
# query success
# attempt number 557
# query success
# attempt number 558
# query success
# attempt number 559
# query success
# attempt number 560
# query success
# attempt number 561
# query success
# attempt number 562
# query success
# attempt number 563
# query success
# attempt number 564
# query success
# attempt number 565
# query success
# attempt number 566
# query success
# attempt number 567
# query success
# attempt number 568
# query success
# attempt number 569
# query success
# attempt number 570
# query success
# attempt number 571
# query success
# attempt number 572
# query success
# attempt number 573
# query success
# attempt number 574
# query success
# attempt number 575
# query success
# attempt number 576
# query success
# attempt number 577
# query success
# attempt number 578
# query success
# attempt number 579
# query success
# attempt number 580
# query success
# attempt number 581
# query success
# attempt number 582
# query success
# attempt number 583
# query success
# attempt number 584
# query success
# attempt number 585
# query success
# attempt number 586
# query success
# attempt number 587
# query success
# attempt number 588
# query success
# attempt number 589
# query success
# attempt number 590
# query success
# attempt number 591
# query success
# attempt number 592
# query success
# attempt number 593
# query success
# attempt number 594
# query success
# attempt number 595
# query success
# attempt number 596
# query success
# attempt number 597
# query success
# attempt number 598
# query success
# attempt number 599
# query success
# attempt number 600
# query success
# attempt number 601
# query success
# attempt number 602
# query success
# attempt number 603
# query success
# attempt number 604
# query success
# attempt number 605
# query success
# attempt number 606
# query success
# attempt number 607
# query success
# attempt number 608
# query success
# attempt number 609
# query success
# attempt number 610
# query success
# attempt number 611
# query success
# attempt number 612
# query success
# attempt number 613
# query success
# attempt number 614
# query success
# attempt number 615
# query success
# attempt number 616
# query success
# attempt number 617
# query success
# attempt number 618
# query success
# attempt number 619
# query success
# attempt number 620
# query success
# attempt number 621
# query success
# attempt number 622
# query success
# attempt number 623
# query success
# attempt number 624
# query success
# attempt number 625
# query success
# attempt number 626
# query success
# attempt number 627
# query success
# attempt number 628
# query success
# attempt number 629
# query success
# attempt number 630
# query success
# attempt number 631
# query success
# attempt number 632
# query success
# attempt number 633
# query success
# attempt number 634
# query success
# attempt number 635
# query success
# attempt number 636
# query success
# attempt number 637
# query success
# attempt number 638
# query success
# attempt number 639
# query success
# attempt number 640
# query success
# attempt number 641
# query success
# attempt number 642
# query success
# attempt number 643
# query success
# attempt number 644
# query success
# attempt number 645
# query success
# attempt number 646
# query success
# attempt number 647
# query success
# attempt number 648
# query success
# attempt number 649
# query success
# attempt number 650
# query success
# attempt number 651
# query success
# attempt number 652
# query success
# attempt number 653
# query success
# attempt number 654
# query success
# attempt number 655
# query success
# attempt number 656
# query success
# attempt number 657
# query success
# attempt number 658
# query success
# attempt number 659
# query success
# attempt number 660
# query success
# attempt number 661
# query success
# attempt number 662
# query success
# attempt number 663
# query success
# attempt number 664
# query success
# attempt number 665
# query success
# attempt number 666
# query success
# attempt number 667
# query success
# attempt number 668
# query success
# attempt number 669
# query success
# attempt number 670
# query success
# attempt number 671
# query success
# attempt number 672
# query success
# attempt number 673
# query success
# attempt number 674
# query success
# attempt number 675
# query success
# attempt number 676
# query success
# attempt number 677
# query success
# attempt number 678
# query success
# attempt number 679
# query success
# attempt number 680
# query success
# attempt number 681
# query success
# attempt number 682
# query success
# attempt number 683
# query success
# attempt number 684
# query success
# attempt number 685
# query success
# attempt number 686
# query success
# attempt number 687
# query success
# attempt number 688
# query success
# attempt number 689
# query success
# attempt number 690
# query success
# attempt number 691
# query success
# attempt number 692
# query success
# attempt number 693
# query success
# attempt number 694
# query success
# attempt number 695
# query success
# attempt number 696
# query success
# attempt number 697
# query success
# attempt number 698
# query success
# attempt number 699
# query success
# attempt number 700
# query success
# No. of records in df: 70,099

# %%
# save or read in API results
# os_gdf.to_file(os.path.join(data_dir, "os_bld-fts-building-1_camden-full.gpkg"))
# os_gdf = gpd.read_file("os_bld-fts-building-1_camden-full.gpkg")

# %%
# filter the OS data to the LAD area
# os_clip_gdf = os_gdf.loc[
#     os_gdf.within(area_geom.iloc[0])
#     ].copy()

# os_clip_gdf.to_file(os.path.join(data_dir, "os_bld-fts-building-1_camden-extent.gpkg"))
os_clip_gdf = gpd.read_file(os.path.join(data_dir, "os_bld-fts-building-1_camden-extent.gpkg"))

# %%
os_clip_gdf.head()
# Out:
#                                    osid versiondate  \
# 0  000100ea-e322-419a-82d8-d2be8b3a2834  2022-09-18
# 1  000178ea-1761-4443-a6d6-81b1b19d6ffc  2022-09-24
# 2  0001e4ed-d5eb-44bb-980a-a05db5ea0b4b  2022-09-18
# 3  00038807-93f3-47b6-b007-654a0f58b4ed  2022-09-18
# 4  000404cb-f48f-4208-bcf7-0a5c4f3681d1  2022-08-26
#
#                                             geometry
# 0  POLYGON ((528963.600 183555.700, 528962.650 18...
# 1  POLYGON ((529377.400 184677.550, 529376.300 18...
# 2  POLYGON ((530217.900 182087.100, 530226.300 18...
# 3  POLYGON ((528292.450 187096.550, 528294.900 18...
# 4  POLYGON ((528981.400 185659.650, 528977.750 18...

# %% [markdown]
# # Analysis

# %%
# quick comparison before doing full intersection
# this is the total length of listed buildings perimiters as a % of the total length of OS building perimiters in the same bounding box
# a good estimate for what the max % of copying OS data might be if all listed building geoms are copied directly

pct_worst_case = sum(cmd_gdf.length) / sum(os_clip_gdf.length)
print("Worst-case match estimate: {:%}".format(round(pct_worst_case,3)))
print("(total listed building geometry perimeter length as a % of total OS building geometry perimiter length)")
# Out:
# Worst-case match estimate: 10.800000%
# (total listed building geometry perimeter length as a % of total OS building geometry perimiter length)

# %%
# tidy names up to use in intersection and create area fields for each dataset
cmd_gdf["area"] = cmd_gdf["geometry"].area

cmd_gdf_join = cmd_gdf[["reference", "area", "geometry"]].copy()
cmd_gdf_join.columns = ["cmd_ref", "cmd_area", "geometry"]

os_clip_gdf["os_area"] = os_clip_gdf["geometry"].area
os_clip_gdf.rename(columns={"osid":"os_ref"}, inplace=True)

# %% [markdown]
# ### Intersection

# %%
# first overlay to see which OS geoms match to listed building ones
cmd_os_join_gdf = gpd.overlay(
    cmd_gdf_join, 
    os_clip_gdf,
    how = "intersection", 
    keep_geom_type=False,
)

nrow(cmd_gdf_join)
nrow(os_clip_gdf)
nrow(cmd_os_join_gdf)

cmd_os_join_gdf["int_area"] = cmd_os_join_gdf["geometry"].area

# calculate intersection areas
cmd_os_join_gdf["cmd_int_pct"] = cmd_os_join_gdf["int_area"] / cmd_os_join_gdf["cmd_area"]
cmd_os_join_gdf["os_int_pct"] = cmd_os_join_gdf["int_area"] / cmd_os_join_gdf["os_area"]

# add a count field for the number of cmd > OS matches
cmd_os_join_gdf["os_match_count"] = cmd_os_join_gdf.groupby("cmd_ref")["cmd_ref"].transform("count")
# Out:
# No. of records in df: 1,961
# No. of records in df: 51,055
# No. of records in df: 8,162

# %% [markdown]
# ### Direct matches

# %%
# CHECK FOR DIRECT MATCHES

threshold = 0.9

direct_matches = cmd_os_join_gdf[(cmd_os_join_gdf["cmd_int_pct"] >= threshold) & (cmd_os_join_gdf["os_int_pct"] > threshold)]
direct_match_pct = len(direct_matches) / len(os_clip_gdf)

print(f"no. of direct matches between listed building outlines and OS buildings: {len(direct_matches)}")
print(f"which equates to {round(direct_match_pct, 4):%} of all OS building geometries in area")
print("")

pct_best_case = sum(direct_matches.length) / sum(os_clip_gdf.length)
print("Best-case match estimate: {:%}".format(round(pct_best_case,3)))
print("(total matched listed building geometry perimeter length as a % of total OS building geometry perimiter length)")


map_os = os_clip_gdf[os_clip_gdf["os_ref"].isin(direct_matches["os_ref"])].explore(
    color = "blue",
    tooltip = False,
    tiles = "CartoDB positron"
)

cmd_gdf[cmd_gdf["reference"].isin(direct_matches["cmd_ref"])].explore(
    m = map_os,
    color = "red",
    # tooltip = False,
    style_kwds = {
        "fillOpacity" : "0"
        }
)
# Out:
# no. of direct matches between listed building outlines and OS buildings: 462
# which equates to 0.900000% of all OS building geometries in area
#
# Best-case match estimate: 1.700000%
# (total matched listed building geometry perimeter length as a % of total OS building geometry perimiter length)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0cf3e84836a40edbebc4713674a7b05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0cf3e84836a40edbebc4713674a7b05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0cf3e84836a40edbebc4713674a7b05 = L.map(
#                 &quot;map_e0cf3e84836a40edbebc4713674a7b05&quot;,
#                 {
#                     center: [51.54142234060502, -0.15435881158970988],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e0cf3e84836a40edbebc4713674a7b05);
#
#
#
#
#
#             var tile_layer_6f91a1d3d435f254fa4c941984fcea2a = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e0cf3e84836a40edbebc4713674a7b05);
#
#
#             map_e0cf3e84836a40edbebc4713674a7b05.fitBounds(
#                 [[51.51272243637148, -0.19999678402957777], [51.57012224483855, -0.10872083914984201]],
#                 {}
#             );
#
#
#         function geo_json_aab8c08de9f959a95f0c32a8c93182ca_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_aab8c08de9f959a95f0c32a8c93182ca_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_aab8c08de9f959a95f0c32a8c93182ca_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_aab8c08de9f959a95f0c32a8c93182ca_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_aab8c08de9f959a95f0c32a8c93182ca_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_aab8c08de9f959a95f0c32a8c93182ca.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_aab8c08de9f959a95f0c32a8c93182ca_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_aab8c08de9f959a95f0c32a8c93182ca = L.geoJson(null, {
#                 onEachFeature: geo_json_aab8c08de9f959a95f0c32a8c93182ca_onEachFeature,
#
#                 style: geo_json_aab8c08de9f959a95f0c32a8c93182ca_styler,
#                 pointToLayer: geo_json_aab8c08de9f959a95f0c32a8c93182ca_pointToLayer
#         });
#
#         function geo_json_aab8c08de9f959a95f0c32a8c93182ca_add (data) {
#             geo_json_aab8c08de9f959a95f0c32a8c93182ca
#                 .addData(data)
#                 .addTo(map_e0cf3e84836a40edbebc4713674a7b05);
#         }
#             geo_json_aab8c08de9f959a95f0c32a8c93182ca_add({&quot;bbox&quot;: [-0.19999678402957777, 51.51272243637148, -0.10872083914984201, 51.57012224483855], &quot;features&quot;: [{&quot;bbox&quot;: [-0.12449384419342793, 51.52269846965654, -0.12422576687922156, 51.52284079687625], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.12442054101946173, 51.52269846965654], [-0.12429840567987492, 51.52272394479919], [-0.1242888351655942, 51.52270743398231], [-0.12425197809101123, 51.5227154327459], [-0.1242776348726821, 51.52276142717744], [-0.12422576687922156, 51.522772693094154], [-0.12426693378275785, 51.52284079687625], [-0.124

# %% [markdown]
# ### Extending match limits through dissolving

# %%
# dissolve matching OS geometries

# lookup for cmd and os ids where matches are 1:1 or 1:many (where the many OS matches are each > 20%)
cmd_os_lookup = cmd_os_join_gdf[
    (cmd_os_join_gdf["os_match_count"] == 1) | ((cmd_os_join_gdf["os_match_count"] > 1) & (cmd_os_join_gdf["os_int_pct"] > 0.2))
    ][["cmd_ref", "os_ref"]]

# inner join to lookup and then dissolve OS geoms grouped by the listed building ref
os_dissolved = os_clip_gdf.merge(
    cmd_os_lookup,
    how = "inner",
    on = "os_ref"
).dissolve(
    by = "cmd_ref"
)

# %%
# map dissolved version of OS geometries with listed buildings they match to 
# map_os = os_dissolved.explore(
#     color = "blue",
#     tooltip = False,
#     tiles = "CartoDB positron"
# )

# cmd_gdf.explore(
#     m = map_os,
#     color = "red",
#     # tooltip = False,
#     style_kwds = {
#         "fillOpacity" : "0"
#         }
# )

# %%
# tidy dissolved table and re-calculate area for new dissolved geometries
os_dissolved.reset_index(inplace = True)
os_dissolved["os_area"] = os_dissolved["geometry"].area

os_dissolved.head()
# Out:
#   cmd_ref                                           geometry  \
# 0  LB1000  POLYGON ((528980.700 183419.600, 528980.950 18...
# 1  LB1001  POLYGON ((528893.856 183429.075, 528892.262 18...
# 2  LB1002  POLYGON ((528802.050 183546.750, 528803.150 18...
# 3  LB1003  POLYGON ((528791.151 183558.500, 528792.900 18...
# 4  LB1004  POLYGON ((528762.700 183535.500, 528769.950 18...
#
#                                  os_ref versiondate      os_area
# 0  0343fed1-35c9-4317-847b-80ede710bbac  2022-08-26    56.315000
# 1  000df1d7-e2e5-4239-9fad-072da8318c61  2022-09-18  1732.205380
# 2  3297611f-46d9-4aa8-acef-1b6b27565809  2022-08-26   117.205750
# 3  6c0a7631-f87e-423d-bdaf-79f08969f852  2022-08-26   164.944887
# 4  4e71f146-97ed-4e08-ba34-33de7fe6e19a  2022-11-28   237.331250

# %%
# intersect listed buildings with dissolved OS geometries
cmd_join_diss = gpd.overlay(
    cmd_gdf_join, 
    os_dissolved.reset_index(),
    how = "intersection", 
    keep_geom_type=False,
)

# filter to just those which have matching references (i.e. the dissolved OS geometry is based on the listed building geom)

cmd_join_diss = cmd_join_diss[cmd_join_diss["cmd_ref_1"] == cmd_join_diss["cmd_ref_2"]]
cmd_join_diss["int_area"] = cmd_join_diss["geometry"].area

nrow(cmd_gdf_join)
nrow(cmd_join_diss)
cmd_join_diss.head()
# Out:
# No. of records in df: 1,961
# No. of records in df: 1,518
#   cmd_ref_1     cmd_area  index cmd_ref_2  \
# 0    LB1859   251.340384    675    LB1859
# 1    LB1872  2711.157851    686    LB1872
# 2    LB1531   626.057066    476    LB1531
# 3    LB1533  1180.225467    477    LB1533
# 6     LB423   164.543118    980     LB423
#
#                                  os_ref versiondate      os_area  \
# 0  63303935-2b4a-48c6-baba-a4eac149e642  2022-08-26   264.922069
# 1  71bc0a46-3317-4d0e-ba77-12d4e2a87d1c  2024-01-29  2321.299950
# 2  c5c77ead-90b6-4670-ae12-2822379019a0  2022-09-18   589.548559
# 3  135b76dd-12cc-471b-ba7e-203ad9c19e43  2023-06-03  1180.217500
# 6  0d9a602e-e89f-4fad-ba83-0c5d9337a8f8  2022-08-26   159.967500
#
#                                             geometry     int_area
# 0  POLYGON ((529791.773 183548.406, 529794.067 18...   250.559855
# 1  POLYGON ((526706.550 184144.451, 526706.301 18...  2317.468171
# 2  POLYGON ((529528.932 181785.850, 529531.210 18...   589.518904
# 3  POLYGON ((530161.652 181082.295, 530159.700 18...  1178.524689
# 6  POLYGON ((530117.506 181081.231, 530117.508 18...   159.593200

# %%
# check some examples from table above to see how area breakdowns work

ref = "LB446"

map_os = os_dissolved[os_dissolved["cmd_ref"] == ref].explore(
    color = "blue",
    tooltip = False,
    tiles = "CartoDB positron"
)

cmd_gdf[cmd_gdf["reference"] == ref].explore(
    m = map_os,
    color = "red",
    # tooltip = False,
    style_kwds = {
        "fillOpacity" : "0.3"
        }
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bdd8af3c905f0832645986bafbd1185 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bdd8af3c905f0832645986bafbd1185&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bdd8af3c905f0832645986bafbd1185 = L.map(
#                 &quot;map_6bdd8af3c905f0832645986bafbd1185&quot;,
#                 {
#                     center: [51.52532770529587, -0.13072138104908415],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6bdd8af3c905f0832645986bafbd1185);
#
#
#
#
#
#             var tile_layer_763d84d826aa3712936e0e5ad670f4b0 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6bdd8af3c905f0832645986bafbd1185);
#
#
#             map_6bdd8af3c905f0832645986bafbd1185.fitBounds(
#                 [[51.52513309237147, -0.13108367148768427], [51.525522318220276, -0.13035909061048404]],
#                 {}
#             );
#
#
#         function geo_json_8a468940496c592a1a9623ff6e347a38_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8a468940496c592a1a9623ff6e347a38_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8a468940496c592a1a9623ff6e347a38_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8a468940496c592a1a9623ff6e347a38_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8a468940496c592a1a9623ff6e347a38_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8a468940496c592a1a9623ff6e347a38.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8a468940496c592a1a9623ff6e347a38_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8a468940496c592a1a9623ff6e347a38 = L.geoJson(null, {
#                 onEachFeature: geo_json_8a468940496c592a1a9623ff6e347a38_onEachFeature,
#
#                 style: geo_json_8a468940496c592a1a9623ff6e347a38_styler,
#                 pointToLayer: geo_json_8a468940496c592a1a9623ff6e347a38_pointToLayer
#         });
#
#         function geo_json_8a468940496c592a1a9623ff6e347a38_add (data) {
#             geo_json_8a468940496c592a1a9623ff6e347a38
#                 .addData(data)
#                 .addTo(map_6bdd8af3c905f0832645986bafbd1185);
#         }
#             geo_json_8a468940496c592a1a9623ff6e347a38_add({&quot;bbox&quot;: [-0.13108367148768427, 51.52513309237147, -0.13035909061048404, 51.525522318220276], &quot;features&quot;: [{&quot;bbox&quot;: [-0.13108367148768427, 51.52513309237147, -0.13035909061048404, 51.525522318220276], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.13038458502102532, 51.52543123618182], [-0.13040749058438317, 51.52545273411605], [-0.13042797298624914, 51.52544541670385], [-0.1305134807473937, 51.525522318220276], [-0.13056560041411544, 51.52549931800946], [-0.1305134534085578, 51.52545262414658], [-0.13054865549883626, 51.52543789745433], [-0

# %%
# not all camden listed buildings intersect so rather than using overlay table, left join to it from the original listed building table
cmd_match_areas = cmd_gdf_join[["cmd_ref", "cmd_area", "geometry"]].merge(
    cmd_join_diss[["cmd_ref_1", "os_area", "int_area"]],
    left_on = "cmd_ref",
    right_on = "cmd_ref_1",
    how = "left"
)

cmd_match_areas["cmd_int_pct"] = cmd_match_areas["int_area"] / cmd_match_areas["cmd_area"]
cmd_match_areas["os_int_pct"] = cmd_match_areas["int_area"] / cmd_match_areas["os_area"]

cmd_match_areas.head()
# Out:
#   cmd_ref     cmd_area                                           geometry  \
# 0  LB1859   251.340384  POLYGON ((529794.083 183544.904, 529791.773 18...
# 1  LB1481     2.618381  POLYGON ((525383.827 186281.856, 525383.774 18...
# 2  LB1872  2711.157851  POLYGON ((526706.983 184142.479, 526706.278 18...
# 3  LB1531   626.057066  POLYGON ((529534.796 181777.495, 529525.359 18...
# 4  LB1532     2.462515  POLYGON ((529598.623 181849.781, 529599.345 18...
#
#   cmd_ref_1      os_area     int_area  cmd_int_pct  os_int_pct
# 0    LB1859   264.922069   250.559855     0.996895    0.945787
# 1       NaN          NaN          NaN          NaN         NaN
# 2    LB1872  2321.299950  2317.468171     0.854789    0.998349
# 3    LB1531   589.548559   589.518904     0.941638    0.999950
# 4       NaN          NaN          NaN          NaN         NaN

# %%
cmd_os_lookup.head()
# Out:
#    cmd_ref                                os_ref
# 0   LB1859  63303935-2b4a-48c6-baba-a4eac149e642
# 4   LB1872  71bc0a46-3317-4d0e-ba77-12d4e2a87d1c
# 5   LB1872  832e39f3-5d60-416b-b515-146d9c599d83
# 7   LB1872  d319afa3-1865-4ddc-831a-98b6b3c83f61
# 10  LB1531  c5c77ead-90b6-4670-ae12-2822379019a0

# %%
# set threshold for combined overlap
threshold = 0.8

# table of listed buildings where the combined match to a dissolved OS geometry is over the threshold 
cmd_match_thresh = cmd_match_areas[(cmd_match_areas["cmd_int_pct"] >= threshold) & (cmd_match_areas["os_int_pct"] >= threshold)]

pct_dissolved_matches = len(cmd_match_thresh) / len(cmd_match_areas)


# table of all OS geoms which went into the dissolved geoms which have a match over threshold
# os_match_geoms = cmd_os_lookup[cmd_os_lookup["cmd_ref"].isin(cmd_match_thresh["cmd_ref"])].merge(
#     os_gdf, 
#     how = "inner", 
#     left_on = "os_ref", 
#     right_on="osid")

os_match_geoms = os_clip_gdf.merge(
    cmd_os_lookup[cmd_os_lookup["cmd_ref"].isin(cmd_match_thresh["cmd_ref"])][["os_ref"]].drop_duplicates(),
    how = "inner", 
    on="os_ref"
)

os_no_match_geoms = os_clip_gdf.merge(
    cmd_os_lookup[~cmd_os_lookup["cmd_ref"].isin(cmd_match_thresh["cmd_ref"])][["os_ref"]].drop_duplicates(),
    how = "inner", 
    on="os_ref"
)

pct_os_match_geoms = len(os_match_geoms) / len(os_clip_gdf)

print("{} out of {} listed  building geoms have a combined match over threshold to OS dissolved geoms".format(len(cmd_match_thresh), len(cmd_gdf_join)))
print("this equates to {:%} %".format(round(pct_dissolved_matches, 3)))

print("")
print("{} out of {} distinct OS building geoms are included in the dissolved geoms which match listed building outlines".format(len(os_match_geoms), len(os_clip_gdf)))
print("this equates to {:%} %".format(round(pct_os_match_geoms, 3)))

print("")
pct_middle_case = sum(cmd_match_thresh.length) / sum(os_clip_gdf.length)
print("Middle-case match estimate: {:%}".format(round(pct_middle_case,3)))
print("(total dissolve-matched listed building geometry perimeter length as a % of total OS building geometry perimiter length)")
# Out:
# 1112 out of 1961 listed  building geoms have a combined match over threshold to OS dissolved geoms
# this equates to 56.700000% %
#
# 4183 out of 51055 distinct OS building geoms are included in the dissolved geoms which match listed building outlines
# this equates to 8.200000% %
#
# Middle-case match estimate: 6.400000%
# (total dissolve-matched listed building geometry perimeter length as a % of total OS building geometry perimiter length)

# %%
# map_os = os_no_match_geoms.explore(
#     color = "#68afff",  # blue for geoms not matched
#     tooltip = False,
#     tiles = "CartoDB positron",
# )

# map_os2 = os_match_geoms.explore(
#     m = map_os,
#     color = "#53ffa2",  # green for geoms matched
#     tooltip = False
# )

# cmd_gdf_join.explore(
#     m = map_os2,
#     color = "red",
#     # tooltip = False,
#     style_kwds = {
#         "fillOpacity" : "0"
#         }
# )

# %%
# map_os = os_dissolved[~os_dissolved["cmd_ref"].isin(cmd_match_thresh["cmd_ref"])].explore(
#     color = "#68afff",  # blue for geoms not matched
#     tooltip = False,
#     tiles = "CartoDB positron"
# )

# map_os2 = os_dissolved[os_dissolved["cmd_ref"].isin(cmd_match_thresh["cmd_ref"].drop_duplicates())].explore(
#     m = map_os,
#     color = "#53ffa2",  # green for geoms matched
#     tooltip = False
# )

# cmd_gdf_join.explore(
#     m = map_os2,
#     color = "red",
#     # tooltip = False,
#     style_kwds = {
#         "fillOpacity" : "0"
#         }
# )
