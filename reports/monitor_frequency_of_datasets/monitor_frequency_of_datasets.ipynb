# %% [markdown]
# # Overview of Datasets and Frequency report
# **Author**:  Kena Vyas <br>
# **Date**:  December 2024 <br>
# **Dataset Scope**: <br>
# Overview of Dataset table includes all Datasets <br>
# Frequency report has Non-ODP and Non-category type datasets <br>
# **Report Type**: Ad-hoc <br>
#
# **Purpose**: <br>
# Overview of Datasets:
# Retrieves the overview of datasets from the Config Manager and improves the report by including additional fields such as the organization of the most recent resource and the entity count.
#
# Frequency Report:
# Identifies all datasets that have not been updated within their assigned refresh frequency, highlighting those overdue for updates.

# %%
# pip install pandas beautifulsoup4 lxml requests

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import json

# %%
response = requests.get("https://config-manager-prototype.herokuapp.com/reporting/overview-of-datasets")
bs = BeautifulSoup(response.content, 'html.parser')
table = bs.find('table')
overview_of_datasets = pd.read_html(str(table))[0]
# Out:
# /tmp/ipykernel_5389/166521801.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   overview_of_datasets = pd.read_html(str(table))[0]

# %%
datasette_url = "https://datasette.planning.data.gov.uk/"

params = urllib.parse.urlencode({
    "sql": f"""
    select dataset, name from dataset where collection != "" group by dataset
    """,
    "_size": "max"
})
url = f"{datasette_url}digital-land.csv?{params}"
get_dataset_name = pd.read_csv(url)
overview_of_datasets.columns = overview_of_datasets.columns.str.lower()
overview_of_datasets = pd.merge(get_dataset_name, overview_of_datasets, on='name', how='inner')

# %%
datasette_url = "https://datasette.planning.data.gov.uk/"

#get organisation for each dataset
params = urllib.parse.urlencode({
    "sql": f"""
    SELECT 
    organisation,
    organisation_name,
    dataset,
    rn
FROM (
    SELECT *,
           ROW_NUMBER() OVER (PARTITION BY dataset ORDER BY resource_start_date DESC) AS rn
    FROM reporting_historic_endpoints
) AS ranked
WHERE rn = 1 group by dataset;
    """,
    "_size": "max"
})
url = f"{datasette_url}performance.csv?{params}"
get_org = pd.read_csv(url)
overview_of_datasets = pd.merge(overview_of_datasets, get_org[['dataset', 'organisation', 'organisation_name']], on='dataset',how='left')

# %% [markdown]
# ### Overview of Datasets table

# %%
def fetch_entity_count(pipeline):
    url = f"https://www.planning.data.gov.uk/entity.json{f'?prefix={pipeline}' if pipeline else ''}"
    try:
        with urllib.request.urlopen(url) as response:
            data = json.load(response)
            return data.get("count", 0)
    except Exception as e:
        print("Error fetching data:",e)
        return 0
        
overview_of_datasets['entity_count'] = overview_of_datasets['dataset'].apply(fetch_entity_count)
overview_of_datasets
# Out:
#                                 dataset                                name  \
# 0      agricultural-land-classification    Agricultural land classification
# 1                      ancient-woodland                    Ancient woodland
# 2               ancient-woodland-status             Ancient woodland status
# 3    area-of-outstanding-natural-beauty  Area of outstanding natural beauty
# 4                   article-4-direction                 Article 4 direction
# ..                                  ...                                 ...
# 98          tree-preservation-zone-type         Tree preservation zone type
# 99                                 ward                                Ward
# 100                     waste-authority            Waste disposal authority
# 101                 world-heritage-site                 World heritage site
# 102     world-heritage-site-buffer-zone     World heritage site buffer zone
#
#              typology organisations (current/expected)     started  \
# 0           geography                           1  / 1  2024-07-15
# 1           geography                           1  / 1  2021-05-26
# 2            category                           1  / 1  2021-12-03
# 3           geography                           1  / 1  2024-10-03
# 4    legal-instrument                        20  / 307  2022-04-25
# ..                ...                              ...         ...
# 98           category                           0  / 1  2023-09-11
# 99          geography                           1  / 1  2024-07-08
# 100      organisation                           1  / 2  2022-06-06
# 101         geography                           1  / 1  2021-05-27
# 102         geography                           1  / 1  2021-05-27
#
#     endpoints (active/total) most recent endpoint  active resources  \
# 0                     1  / 1           2024-07-09               1.0
# 1                     1  / 1           2024-09-26               1.0
# 2                     1  / 1           2021-12-03               1.0
# 3                     2  / 2           2024-10-01               2.0
# 4                   18  / 19           2024-12-02              23.0
# ..                       ...                  ...               ...
# 98                    1  / 1           2023-09-11               1.0
# 99                    1  / 1           2024-07-08               1.0
# 100                   1  / 1           2022-05-30               1.0
# 101                   2  / 2           2024-09-18               2.0
# 102                   1  / 1           2024-09-18               1.0
#
#      days since update frequency of updates                    organisation  \
# 0                141.0              Unknown   government-organisation:PB202
# 1                 67.0              Monthly   government-organisation:PB202
# 2               1096.0              Monthly   government-organisation:PB202
# 3                 57.0               Ad hoc   government-organisation:PB202
# 4                  0.0               Ad hoc             local-authority:BIR
# ..                 ...                  ...                             ...
# 98               449.0               Ad hoc   government-organisation:D1342
# 99               148.0            Quarterly    government-organisation:D303
# 100              160.0                  NaN   government-organisation:D1342
# 101                3.0               Ad hoc  government-organisation:PB1164
# 102                3.0               Ad hoc  government-organisation:PB1164
#
#                                      organisation_name  entity_count
# 0                                      Natural England           585
# 1                                      Natural England         44373
# 2                                      Natural England             2
# 3                                      Natural England            34
# 4                              Birmingham City Council           263
# ..                                                 ...           ...
# 98   Ministry of Housing, Communities & Local Gover...             3
# 99                      Office for National Statistics             0
# 100  Ministry of Housing, Communities & Local Gover...             0
# 101                                   Historic England            20
# 102                                   Historic England             9
#
# [103 rows x 13 columns]

# %% [markdown]
# ### Downloads Overview table

# %%
overview_of_datasets.to_excel('overview_of_datasets.xlsx', index=False)

# %% [markdown]
# ### Frequency report

# %%
remove_dataset=['article-4-direction','article-4-direction-area','conservation-area', 'conservation-area-document', 'listed-building', 'listed-building-outline', 'tree-preservation-order', 'tree', 'tree-preservation-zone']
overview_of_datasets = overview_of_datasets[overview_of_datasets['typology'] != 'category']
overview_of_datasets = overview_of_datasets[~overview_of_datasets['dataset'].isin(remove_dataset)]
frequency_to_days = {
    'Fortnightly': 14,
    'Monthly': 30,
    'Quarterly': 90,
    'Annually': 365,
}
overview_of_datasets['frequency_in_days'] = overview_of_datasets['frequency of updates'].map(frequency_to_days)
overview_of_datasets = overview_of_datasets.dropna(subset=['frequency_in_days'])
frequency_df = overview_of_datasets[(overview_of_datasets['days since update'] > overview_of_datasets['frequency_in_days'])]
frequency_df
# Out:
#                              dataset                              name  \
# 1                   ancient-woodland                  Ancient woodland
# 10      building-preservation-notice      Building preservation notice
# 35                   flood-risk-zone                   Flood risk zone
# 42  infrastructure-funding-statement  Infrastructure funding statement
# 99                              ward                              Ward
#
#      typology organisations (current/expected)     started  \
# 1   geography                           1  / 1  2021-05-26
# 10  geography                           1  / 1  2021-05-28
# 35  geography                           1  / 1  2023-08-24
# 42   document                           1  / 1  2022-01-05
# 99  geography                           1  / 1  2024-07-08
#
#    endpoints (active/total) most recent endpoint  active resources  \
# 1                    1  / 1           2024-09-26               1.0
# 10                   1  / 1           2024-10-02               1.0
# 35                        /                  NaN               0.0
# 42                        /                  NaN               0.0
# 99                   1  / 1           2024-07-08               1.0
#
#     days since update frequency of updates                    organisation  \
# 1                67.0              Monthly   government-organisation:PB202
# 10               32.0          Fortnightly  government-organisation:PB1164
# 35              467.0            Quarterly   government-organisation:EA199
# 42             1063.0             Annually                             NaN
# 99              148.0            Quarterly    government-organisation:D303
#
#                  organisation_name  entity_count  frequency_in_days
# 1                  Natural England         44373               30.0
# 10                Historic England             6               14.0
# 35              Environment Agency        550621               90.0
# 42                             NaN           197              365.0
# 99  Office for National Statistics             0               90.0

# %% [markdown]
# ### Downloads Frequency table

# %%
frequency_df.to_excel('frequency_of_datasets.xlsx', index=False)
