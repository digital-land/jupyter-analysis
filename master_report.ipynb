# %% [markdown]
# This report provides status information on the most recent endpoints for a hardcoded list of prioritised list of LPAs, or organisations from an input.
#
# The input should be called 'input.csv' and contain one column, 'organisation' that has the organisation codes for the LPAs to be included in the report.

# %%
from datetime import datetime as dt
from IPython.display import display
import urllib
import numpy as np
import math
import pandas as pd
import ipywidgets as widgets
import requests
import urllib.parse
import os

# %%
# Get input from .csv or use default prioritised LPAs
input_path = './input.csv'
if os.path.isfile(input_path):
    input_df = pd.read_csv(input_path)
    organisation_list = input_df['organisation'].tolist()
    print('Input file found. Using', len(organisation_list), 'organisations from input file.')
else:
    organisation_list = ['local-authority-eng:BUC', 'local-authority-eng:DAC', 'local-authority-eng:DNC',
    'local-authority-eng:GLO', 'local-authority-eng:CMD', 'local-authority-eng:LBH', 'local-authority-eng:SWK',
    'local-authority-eng:MDW', 'local-authority-eng:NET', 'local-authority-eng:BIR', 'local-authority-eng:CAT',
    'local-authority-eng:EPS', 'local-authority-eng:BNE', 'local-authority-eng:GAT', 'local-authority-eng:GRY',
    'local-authority-eng:KTT', 'local-authority-eng:SAL', 'local-authority-eng:TEW', 'local-authority-eng:WBK',
    'local-authority-eng:DST', 'local-authority-eng:DOV', 'local-authority-eng:LIV', 'local-authority-eng:RDB',
    'local-authority-eng:WFT', 'local-authority-eng:NLN', 'local-authority-eng:NSM', 'local-authority-eng:SLF',
    'local-authority-eng:WRL' ]
    print('Input file not found. Using default list of organisations.')
# Out:
# Input file not found. Using default list of organisations.

# %%
# Get organisation info
organisation_info_df = pd.read_csv('https://raw.githubusercontent.com/digital-land/organisation-collection/main/data/local-authority.csv')
organisation_info_df.head()
organisation_name_dict = {}
for organisation in organisation_list:
    organisation_code = organisation.split(':')[1]
    organisation_name = organisation_info_df.loc[organisation_info_df['reference'] == organisation_code].iloc[0]['name']
    organisation_name_dict[organisation] = organisation_name

# %%
datasette_url = "https://datasette.planning.data.gov.uk/"

def update_dataframe(organisation):
    global result_df  
    if organisation:
        query = f" s.organisation = '{organisation}'"
    else:
        query = f" s.organisation LIKE '%'"
    params = urllib.parse.urlencode({
        "sql": f"""
        select
          e.endpoint_url,
          l.status,
          s.collection,
          group_concat(DISTINCT sp.pipeline) as pipelines,
          s.organisation,
          o.name,
          max(l.entry_date) maxentrydate,
          max(e.entry_date) entrydate,
          e.end_date
        from
          log l
          inner join source s on l.endpoint = s.endpoint
          inner join organisation o on s.organisation=o.organisation
          inner join endpoint e on l.endpoint = e.endpoint
          inner join source_pipeline sp on s.source = sp.source
        where
           {query} and not collection="brownfield-land"
        group by
          l.endpoint,
          l.status
        order by
          l.endpoint,
          s.collection,
          maxentrydate desc
        """,
        "_size": "max"
    })
    
    url = f"{datasette_url}digital-land.csv?{params}"
    df = pd.read_csv(url)
    result_df = df
    return df

def update_dataframe_latest_status(organisation):
    global new_df
    all_endpoints=update_dataframe(organisation)
    new_df=all_endpoints.copy()
    new_df['maxentrydate'] = pd.to_datetime(new_df['maxentrydate'])
    new_df['last_status'] = None
    new_df['last_updated_date'] = None
    new_df['date_last_status_200'] = None
    
    for index, row in new_df.iterrows():
        if index < len(new_df) - 1 and (row['status']!=200 or pd.isna(row['status'])):
            if row['endpoint_url'] == new_df.at[index + 1, 'endpoint_url']:
                new_df.at[index, 'last_status'] = new_df.at[index + 1, 'status']
                new_df.at[index, 'last_updated_date'] = new_df.at[index + 1, 'maxentrydate']   
    
    new_df.drop_duplicates(subset='endpoint_url', keep='first', inplace=True)
    new_df.reset_index(drop=True, inplace=True)
    for index, row in new_df.iterrows():
        if row['last_status'] is not None:
            if row['last_status'] != 200  or row['last_status'] is None:
                filtered_df = all_endpoints[(all_endpoints['endpoint_url'] == row['endpoint_url'] ) & (all_endpoints['status'] == 200)]
                if not filtered_df.empty:
                    new_df.at[index, 'date_last_status_200'] = filtered_df['maxentrydate'].values[0][:19] 
    return new_df

collection_list = ['article-4-direction', 'article-4-direction-area', 'conservation-area', 'conservation-area-document', 'listed-building-outline', 'tree-preservation-order', 'tree-preservation-zone', 'tree']
pipelines_list = ['article-4-direction', 'article-4-direction-area', 'conservation-area', 'conservation-area-document', 'listed-building-outline', 'tree-preservation-order', 'tree-preservation-zone', 'tree', 'tree,tree-preservation-order', 'tree-preservation-order,tree-preservation-zone']
all_orgs_recent_endpoints={}
for organisation in organisation_list:
    recent_endpoints_df = update_dataframe_latest_status(organisation)
    recent_endpoints_df = recent_endpoints_df[recent_endpoints_df['pipelines'].isin(pipelines_list)]
    all_orgs_recent_endpoints[organisation] = recent_endpoints_df

# %%
pd.set_option('display.max_colwidth', None)

def compute_cell_colour(status):
    if status == 200:
        return 'background-color: green'
    elif status == 'No endpoint':
        return 'background-color: orange'
    else:
        return 'background-color: red'

rows_list = []
for organisation in organisation_list:
    df = all_orgs_recent_endpoints[organisation]
    if organisation == 'local-authority-eng:BIR': print(df)
    # Revisit this drop duplicates - figure out how we should be handling multiple endpoints for same collection
    # Take the most recent entrydate/maxentrydate?
    df = df.drop_duplicates(subset='pipelines', keep='first')
    try:
        name = organisation_name_dict[organisation]
    except:
        name = organisation
    statuses = {}
    for collection in pipelines_list:
        status = df[df['pipelines'] == collection]['status']
        if ',' in collection:
            datasets = collection.split(',')
            if status.empty or pd.isna(status.values[0]):
                status = 'No endpoint'
            else:
                status = int(status.values[0])
            for i in datasets:
                statuses[i] = status
        else:
            if status.empty or pd.isna(status.values[0]):
                status = 'No endpoint'
            else:
                status = int(status.values[0])
            statuses[collection] = status
    new_row = {'organisation': name}
    new_row.update(statuses)
    rows_list.append(new_row)

output_df = pd.DataFrame(rows_list, columns=['organisation', *collection_list])
output_df.style.applymap(compute_cell_colour, subset=collection_list)
# Out:
# Empty DataFrame
# Columns: [endpoint_url, status, collection, pipelines, organisation, name, maxentrydate, entrydate, end_date, last_status, last_updated_date, date_last_status_200]
# Index: []
# /tmp/ipykernel_9050/3958972033.py:45: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   output_df.style.applymap(compute_cell_colour, subset=collection_list)
# <style type="text/css">
# #T_f94cb_row0_col1, #T_f94cb_row0_col4, #T_f94cb_row0_col6, #T_f94cb_row0_col7, #T_f94cb_row0_col8, #T_f94cb_row1_col1, #T_f94cb_row1_col2, #T_f94cb_row1_col3, #T_f94cb_row1_col4, #T_f94cb_row1_col5, #T_f94cb_row1_col6, #T_f94cb_row1_col7, #T_f94cb_row1_col8, #T_f94cb_row2_col1, #T_f94cb_row2_col4, #T_f94cb_row2_col5, #T_f94cb_row2_col6, #T_f94cb_row2_col7, #T_f94cb_row2_col8, #T_f94cb_row3_col1, #T_f94cb_row3_col4, #T_f94cb_row3_col6, #T_f94cb_row3_col7, #T_f94cb_row3_col8, #T_f94cb_row4_col4, #T_f94cb_row4_col6, #T_f94cb_row4_col7, #T_f94cb_row4_col8, #T_f94cb_row5_col1, #T_f94cb_row5_col4, #T_f94cb_row5_col6, #T_f94cb_row5_col7, #T_f94cb_row6_col4, #T_f94cb_row6_col8, #T_f94cb_row7_col1, #T_f94cb_row7_col3, #T_f94cb_row7_col4, #T_f94cb_row7_col8, #T_f94cb_row8_col4, #T_f94cb_row9_col1, #T_f94cb_row9_col2, #T_f94cb_row9_col3, #T_f94cb_row9_col4, #T_f94cb_row9_col5, #T_f94cb_row9_col6, #T_f94cb_row9_col7, #T_f94cb_row9_col8, #T_f94cb_row10_col1, #T_f94cb_row10_col4, #T_f94cb_row10_col8, #T_f94cb_row11_col1, #T_f94cb_row11_col2, #T_f94cb_row11_col3, #T_f94cb_row11_col4, #T_f94cb_row11_col5, #T_f94cb_row11_col6, #T_f94cb_row11_col7, #T_f94cb_row11_col8, #T_f94cb_row12_col1, #T_f94cb_row12_col2, #T_f94cb_row12_col3, #T_f94cb_row12_col4, #T_f94cb_row12_col5, #T_f94cb_row12_col6, #T_f94cb_row12_col7, #T_f94cb_row12_col8, #T_f94cb_row13_col1, #T_f94cb_row13_col3, #T_f94cb_row13_col4, #T_f94cb_row13_col6, #T_f94cb_row13_col7, #T_f94cb_row13_col8, #T_f94cb_row14_col1, #T_f94cb_row14_col4, #T_f94cb_row14_col6, #T_f94cb_row14_col7, #T_f94cb_row14_col8, #T_f94cb_row15_col1, #T_f94cb_row15_col2, #T_f94cb_row15_col3, #T_f94cb_row15_col4, #T_f94cb_row15_col5, #T_f94cb_row15_col6, #T_f94cb_row15_col7, #T_f94cb_row15_col8, #T_f94cb_row16_col1, #T_f94cb_row16_col2, #T_f94cb_row16_col3, #T_f94cb_row16_col4, #T_f94cb_row16_col5, #T_f94cb_row16_col6, #T_f94cb_row16_col7, #T_f94cb_row16_col8, #T_f94cb_row17_col1, #T_f94cb_row17_col2, #T_f94cb_row17_col3, #T_f94cb_row17_col4, #T_f94cb_row17_col5, #T_f94cb_row17_col6, #T_f94cb_row17_col7, #T_f94cb_row17_col8, #T_f94cb_row18_col1, #T_f94cb_row18_col2, #T_f94cb_row18_col3, #T_f94cb_row18_col4, #T_f94cb_row18_col5, #T_f94cb_row18_col6, #T_f94cb_row18_col7, #T_f94cb_row18_col8, #T_f94cb_row19_col1, #T_f94cb_row19_col2, #T_f94cb_row19_col3, #T_f94cb_row19_col4, #T_f94cb_row19_col5, #T_f94cb_row19_col6, #T_f94cb_row19_col7, #T_f94cb_row19_col8, #T_f94cb_row20_col1, #T_f94cb_row20_col4, #T_f94cb_row20_col6, #T_f94cb_row20_col7, #T_f94cb_row20_col8, #T_f94cb_row21_col1, #T_f94cb_row21_col2, #T_f94cb_row21_col3, #T_f94cb_row21_col4, #T_f94cb_row21_col5, #T_f94cb_row21_col6, #T_f94cb_row21_col7, #T_f94cb_row21_col8, #T_f94cb_row22_col1, #T_f94cb_row22_col2, #T_f94cb_row22_col3, #T_f94cb_row22_col4, #T_f94cb_row22_col5, #T_f94cb_row22_col6, #T_f94cb_row22_col7, #T_f94cb_row22_col8, #T_f94cb_row23_col1, #T_f94cb_row23_col2, #T_f94cb_row23_col3, #T_f94cb_row23_col4, #T_f94cb_row23_col5, #T_f94cb_row23_col6, #T_f94cb_row23_col7, #T_f94cb_row23_col8, #T_f94cb_row24_col1, #T_f94cb_row24_col2, #T_f94cb_row24_col3, #T_f94cb_row24_col4, #T_f94cb_row24_col5, #T_f94cb_row24_col6, #T_f94cb_row24_col7, #T_f94cb_row24_col8, #T_f94cb_row25_col1, #T_f94cb_row25_col2, #T_f94cb_row25_col3, #T_f94cb_row25_col4, #T_f94cb_row25_col5, #T_f94cb_row25_col6, #T_f94cb_row25_col7, #T_f94cb_row25_col8, #T_f94cb_row26_col1, #T_f94cb_row26_col2, #T_f94cb_row26_col4, #T_f94cb_row26_col5, #T_f94cb_row26_col6, #T_f94cb_row26_col7, #T_f94cb_row26_col8, #T_f94cb_row27_col1, #T_f94cb_row27_col2, #T_f94cb_row27_col3, #T_f94cb_row27_col4, #T_f94cb_row27_col5, #T_f94cb_row27_col6, #T_f94cb_row27_col7, #T_f94cb_row27_col8 {
#   background-color: orange;
# }
# #T_f94cb_row0_col2, #T_f94cb_row0_col3, #T_f94cb_row0_col5, #T_f94cb_row2_col2, #T_f94cb_row2_col3, #T_f94cb_row3_col2, #T_f94cb_row3_col3, #T_f94cb_row3_col5, #T_f94cb_row4_col1, #T_f94cb_row4_col2, #T_f94cb_row4_col3, #T_f94cb_row4_col5, #T_f94cb_row5_col3, #T_f94cb_row5_col5, #T_f94cb_row5_col8, #T_f94cb_row6_col1, #T_f94cb_row6_col2, #T_f94cb_row6_col3, #T_f94cb_row6_col5, #T_f94cb_row6_col6, #T_f94cb_row6_col7, #T_f94cb_row7_col2, #T_f94cb_row7_col5, #T_f94cb_row7_col6, #T_f94cb_row7_col7, #T_f94cb_row8_col1, #T_f94cb_row8_col2, #T_f94cb_row8_col3, #T_f94cb_row8_col5, #T_f94cb_row8_col6, #T_f94cb_row8_col7, #T_f94cb_row8_col8, #T_f94cb_row10_col2, #T_f94cb_row10_col3, #T_f94cb_row10_col5, #T_f94cb_row10_col6, #T_f94cb_row10_col7, #T_f94cb_row13_col2, #T_f94cb_row13_col5, #T_f94cb_row14_col2, #T_f94cb_row14_col3, #T_f94cb_row14_col5, #T_f94cb_row20_col2, #T_f94cb_row20_col3, #T_f94cb_row20_col5, #T_f94cb_row26_col3 {
#   background-color: green;
# }
# #T_f94cb_row5_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_f94cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f94cb_level0_col0" class="col_heading level0 col0" >organisation</th>
#       <th id="T_f94cb_level0_col1" class="col_heading level0 col1" >article-4-direction</th>
#       <th id="T_f94cb_level0_col2" class="col_heading level0 col2" >article-4-direction-area</th>
#       <th id="T_f94cb_level0_col3" class="col_heading level0 col3" >conservation-area</th>
#       <th id="T_f94cb_level0_col4" class="col_heading level0 col4" >conservation-area-document</th>
#       <th id="T_f94cb_level0_col5" class="col_heading level0 col5" >listed-building-outline</th>
#       <th id="T_f94cb_level0_col6" class="col_heading level0 col6" >tree-preservation-order</th>
#       <th id="T_f94cb_level0_col7" class="col_heading level0 col7" >tree-preservation-zone</th>
#       <th id="T_f94cb_level0_col8" class="col_heading level0 col8" >tree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f94cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f94cb_row0_col0" class="data row0 col0" >Buckinghamshire Council</td>
#       <td id="T_f94cb_row0_col1" class="data row0 col1" >No endpoint</td>
#       <td id="T_f94cb_row0_col2" class="data row0 col2" >200</td>
#       <td id="T_f94cb_row0_col3" class="data row0 col3" >200</td>
#       <td id="T_f94cb_row0_col4" class="data row0 col4" >No endpoint</td>
#       <td id="T_f94cb_row0_col5" class="data row0 col5" >200</td>
#       <td id="T_f94cb_row0_col6" class="data row0 col6" >No endpoint</td>
#       <td id="T_f94cb_row0_col7" class="data row0 col7" >No endpoint</td>
#       <td id="T_f94cb_row0_col8" class="data row0 col8" >No endpoint</td>
#     </tr>
#     <tr>
#       <th id="T_f94cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f94cb_row1_col0" class="data row1 col0" >Dacorum Borough Council</td>
#       <td id="T_f94cb_row1_col1" class="data row1 col1" >No endpoint</td>
#       <td id="T_f94cb_row1_col2" class="data row1 col2" >No endpoint</td>
#       <td id="T_f94cb_row1_col3" class="data row1 col3" >No endpoint</td>
#       <td id="T_f94cb_row1_col4" class="data row1 col4" >No endpoint</td>
#       <td id="T_f94cb_row1_col5" class="data row1 col5" >No endpoint</td>
#       <td id="T_f94cb_row1_col6" class="data row1 col6" >No endpoint</td>
#       <td id="T_f94cb_row1_col7" class="data row1 col7" >No endpoint</td>
#       <td id="T_f94cb_row1_col8" class="data row1 col8" >No endpoint</td>
#     </tr>
#     <tr>
#       <th id="T_f94cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f94cb_row2_col0" class="data row2 col0" >Doncaster Metropolitan Borough Council</td>
#       <td id="T_f94cb_row2_col1" class="data row2 col1" >No endpoint</td>
#       <td id="T_f94cb_row2_col2" class="data row2 col2" >200</td>
#       <td id="T_f94cb_row2_col3" class="data row2 col3" >200</td>
#       <td id="T_f94cb_row2_col4" class="data row2 col4" >No endpoint</td>
#       <td id="T_f94cb_row2_col5" class="data row2 col5" >No endpoint</td>
#       <td id="T_f94cb_row2_col6" class="data row2 col6" >No endpoint</td>
#       <td id="T_f94cb_row2_col7" class="data row2 col7" >No endpoint</td>
#       <td id="T_f94cb_row2_col8" class="data row2 col8" >No endpoint</td>
#     </tr>
#     <tr>
