# %% [markdown]
# # Dataset staleness and related issues
#
# The notebook contains a range of queries that can be used to cast light on issues of data quality such as 'staleness'.
#
# ## Using
#
# You need to
#
# 1. Download the digital_land dataset from https://datasette.planning.data.gov.uk/digital-land
# 1. Point the `source_file` variable (below) at your download.
#
# The first time it runs, it takes a few minutes to build some indexes which speed up subsequent queries.
#
# ### Variables
#
# These determine what data is processed.
#
# * source_file - the file you downloaded above
# * collection - the collection to process
# * staleness_days - if data has been collected without changing for this number of days, then consider it to be stale
# * recent_entry_cutoff - used to say if an endpoint was recently added ( greater than this value)
# * organisation - used to show the endpoints for just one organisation.

# %%
import pandas as pd
import urllib.parse
import sqlite3

# %%
datasette_url = "https://datasette.planning.data.gov.uk/"

source_file = "/mnt/c/Users/MarkSmith/Downloads/digital-land_2023)10_26.sqlite3" # or whatever you called your download.
dest_file=  "/mnt/c/Users/MarkSmith/Downloads/entity_2023_10_26_crosstab.csv" # or wherever you want your output

collection = "brownfield-land"
staleness_days=365*3
current_year = "2023"
viewName = F"{collection}_{current_year}".replace("-", "_")

cnx = sqlite3.connect(source_file)

cursor = cnx.cursor()

def add_index (table, column) :
    cnx.execute(F"CREATE INDEX if not exists idx_{table}_{column} ON {table}({column})") 

add_index ("log", "endpoint")
add_index ("log", "resource")
add_index ("log", "status")

add_index ("source", "collection")
add_index ("source", "endpoint")
add_index ("source", "start_date")
add_index ("source", "end_date")

add_index ("endpoint", "endpoint")
add_index ("endpoint", "entry_date")
add_index ("endpoint", "start_date")
add_index ("endpoint", "end_date")

def query_datasette (query_text):
    return pd.read_sql_query(query_text, cnx)

# %%
sql = F"""CREATE VIEW IF NOT EXISTS {viewName} AS
    select organisation, strftime('%Y',ep.entry_date) as year, strftime('%m',ep.entry_date) as month 
	from source src 
	inner join endpoint ep on ep.endpoint = src.endpoint
	where src.collection = "{collection}" 
    and year = "{current_year}"
"""

sql
cnx.execute(sql)

query_datasette(F"SELECT * FROM {viewName}")
# Out:
#                 organisation  year month
# 0    local-authority-eng:WOK  2023    08
# 1    local-authority-eng:LEE  2023    07
# 2    local-authority-eng:BAB  2023    08
# 3    local-authority-eng:NGM  2023    09
# 4    local-authority-eng:BAN  2023    06
# ..                       ...   ...   ...
# 291  local-authority-eng:HRT  2023    09
# 292  local-authority-eng:BNS  2023    09
# 293  local-authority-eng:COT  2023    09
# 294  local-authority-eng:LIF  2023    10
# 295  local-authority-eng:GRT  2023    10
#
# [296 rows x 3 columns]

# %% [markdown]
# # Live endpoints still using HTTP instead of HTTPS
#
# These are candidates for being old, since http (compared with https) was retired years ago.

# %%
http_sql = F"""
  select src.organisation, src.endpoint, ep.entry_date, ep.endpoint_url, ep.start_date, ep.end_date  from source src
  inner join endpoint ep on src.endpoint = ep.endpoint
  where src.collection  = "{collection}"
  and ep.end_date = ""
  and ep.endpoint_url like "http:%"
  order by src.organisation, ep.start_date ASC NULLS LAST
"""

query_datasette(http_sql)
# Out:
#                         organisation  \
# 0   development-corporation:Q6670544
# 1            local-authority-eng:AMB
# 2            local-authority-eng:AMB
# 3            local-authority-eng:AMB
# 4            local-authority-eng:AMB
# ..                               ...
# 71           local-authority-eng:WOI
# 72           local-authority-eng:WYE
# 73           local-authority-eng:WYO
# 74           local-authority-eng:WYO
# 75           local-authority-eng:WYO
#
#                                              endpoint            entry_date  \
# 0   4c238528f325bcca9a03697583d9f39a91ecf1ec1ecb66...  2018-07-05T00:00:00Z
# 1   1945e57b32134a160bfb4972bcd6f86935b4c6fc0bd000...  2019-11-23T00:00:00Z
# 2   239f7a38efe51fb6271d40bd76dd7413fecb458a5c4d1e...  2019-11-23T00:00:00Z
# 3   c0fcdc64525d3be69736427cd397bf5a3c2d68104e8a90...  2018-05-22T00:00:00Z
# 4   533d03f6fd2b5717597c4f3057106b907f4b23c8fb2e7b...  2020-05-21T00:00:00Z
# ..                                                ...                   ...
# 71  30b94b097f288a5f2df6ad2cae6fa403a5599e39bece53...  2018-05-22T00:00:00Z
# 72  36c1c91ee6ec46da952246ce66916adf3200f7b14d42f5...  2018-05-22T00:00:00Z
# 73  466796e9f6e18591dead03d9e7836e02d6494ec1a5ac9e...  2018-05-22T00:00:00Z
# 74  7b6a413b1c1018215fe400dae82e6366b80fb8f89c0240...  2019-11-24T00:00:00Z
# 75  daf78166cf6af62a0b40625a2fd6c8401f27b9fffab4a9...  2019-11-24T00:00:00Z
#
#                                          endpoint_url  start_date end_date
# 0   http://www.queenelizabetholympicpark.co.uk/-/m...
# 1   http://info.ambervalley.gov.uk/shareddatasets/...
# 2   http://info.ambervalley.gov.uk/shareddatasets/...
# 3   http://info.ambervalley.gov.uk/shareddatasets/...  2017-12-22
# 4   http://info.ambervalley.gov.uk/shareddatasets/...  2020-05-21
# ..                                                ...         ...      ...
# 71  http://woking2027.info/res/uploads/WokingBorou...
# 72  http://www.wyreforestdc.gov.uk/media/3585747/W...
# 73  http://data.wycombe.gov.uk/download/planning/b...  2019-06-21
# 74  http://data.wycombe.gov.uk/download/planning/b...  2019-08-21
# 75  http://data.wycombe.gov.uk/download/planning/b...  2019-08-21
#
# [76 rows x 6 columns]

# %% [markdown]
# # Live endpoints with stale data
#
# These are endpoints that have not given us any new data in {staleness_days}.

# %%
sql = F"""
	select src.organisation, src.start_date, src.end_date,  log.endpoint, log.resource, count (log.resource) as c from log 
    inner join source src on src.endpoint = log.endpoint
	where log.status = 200
	and src.end_date = ""
	and src.collection = "{collection}"
    group by 1,2, 3, 4, 5
	having c > {staleness_days}
	order by c desc
	limit 100
"""

query_datasette(sql)
# Out:
#                organisation  start_date end_date  \
# 0   local-authority-eng:ALL  2017-12-20
# 1   local-authority-eng:BDF
# 2   local-authority-eng:CAN  2017-12-01
# 3   local-authority-eng:CAS  2017-12-01
# 4   local-authority-eng:CHR
# ..                      ...         ...      ...
# 95  local-authority-eng:KIR  2018-02-28
# 96  local-authority-eng:BAB  2017-12-21
# 97  local-authority-eng:CHR  2018-12-03
# 98  local-authority-eng:MSU  2017-12-21
# 99  local-authority-eng:BNH
#
#                                              endpoint  \
# 0   9c2e8adfd12b4f474e7d511580029d1e69d1e08a17e0cb...
# 1   f8979dadf073ed0fa1373b6c018fa376833c5aa9e740a2...
# 2   660ed3b8f8bffe8a326dfb597ddce7a3b4c9b28a04fe78...
# 3   b7d3310848346fdcc872fb40dcb80697f05dfa1f593565...
# 4   26ed7ad003da61c66f9656ba61750b14a53b3ac74a1865...
# ..                                                ...
# 95  36440d2479b935805c1d13fcb46b78968ba968c959b9e7...
# 96  cf91b1e94fe298ecf6383060c79b3dd7d030cdfd00bda9...
# 97  9e1b22e993f2219cd48baa60b5f08a77782cd5f347aa22...
# 98  cf91b1e94fe298ecf6383060c79b3dd7d030cdfd00bda9...
# 99  1557e0e322fd55067f4c9d541d7cf2862809b8e2e945d1...
#
#                                              resource     c
# 0   3b694528538878d378fd6892a649fa634f0013ef299331...  1410
# 1   12e709c847614f924fc6bd9dcb9c162816e59623887765...  1410
# 2   4c524bd78ea05989aaaabdcad0cae87d48f4ad9eaf18a4...  1410
# 3   cd0c958ec2843364957c2fd9757151fdfb6659bb8e0d51...  1410
# 4   1a349651d94dfdbdc44773a256313c391c7418f0bcad53...  1410
# ..                                                ...   ...
# 95  93f7961f5e90ed8e26b632353221a0cc955a70fdbe3b01...  1389
# 96  49a918dc51d8d4063061e5b0d257943aa194370ae1f07a...  1387
# 97  c94e35967405344dd2fd4116f2705be22d222407eb82d5...  1387
# 98  49a918dc51d8d4063061e5b0d257943aa194370ae1f07a...  1387
# 99  6cd0ed46a9a905307ff30d8b99fc5ca8b6e1dceb4f3b4f...  1385
#
# [100 rows x 6 columns]

# %% [markdown]
# # Endpoints with no documentation URL
#
# Just from LPAs

# %%
sql = F"""
select organisation, entry_date,  source, start_date from source 
where collection = "{collection}" and documentation_url = ""  and end_date = "" and organisation like "local-authority-eng%"  
order by 2 
"""

query_datasette(sql)
# Out:
#                 organisation            entry_date  \
# 0    local-authority-eng:HAL  2018-05-22T00:00:00Z
# 1    local-authority-eng:BAB  2018-05-22T00:00:00Z
# 2    local-authority-eng:THE  2018-05-22T00:00:00Z
# 3    local-authority-eng:HIG  2018-05-22T00:00:00Z
# 4    local-authority-eng:EXE  2018-05-22T00:00:00Z
# 5    local-authority-eng:BRT  2018-05-22T00:00:00Z
# 6    local-authority-eng:DUR  2018-05-22T00:00:00Z
# 7    local-authority-eng:HAE  2018-05-22T00:00:00Z
# 8    local-authority-eng:EPS  2018-05-22T00:00:00Z
# 9    local-authority-eng:FOR  2018-05-22T00:00:00Z
# 10   local-authority-eng:SKP  2018-05-22T00:00:00Z
# 11   local-authority-eng:WLA  2018-05-22T00:00:00Z
# 12   local-authority-eng:YOR  2018-05-22T00:00:00Z
# 13   local-authority-eng:DAV  2018-05-22T00:00:00Z
# 14   local-authority-eng:NWL  2018-05-22T00:00:00Z
# 15   local-authority-eng:BEN  2018-05-22T00:00:00Z
# 16   local-authority-eng:ELI  2018-05-22T00:00:00Z
# 17   local-authority-eng:FAR  2018-05-22T00:00:00Z
# 18   local-authority-eng:BRW  2018-05-22T00:00:00Z
# 19   local-authority-eng:NOR  2018-05-22T00:00:00Z
# 20   local-authority-eng:NNO  2018-05-22T00:00:00Z
# 21   local-authority-eng:MDE  2018-05-22T00:00:00Z
# 22   local-authority-eng:CAN  2018-05-22T00:00:00Z
# 23   local-authority-eng:CHT  2018-05-22T00:00:00Z
# 24   local-authority-eng:NKE  2018-05-22T00:00:00Z
# 25   local-authority-eng:TAN  2018-05-22T00:00:00Z
# 26   local-authority-eng:NHE  2018-05-22T00:00:00Z
# 27   local-authority-eng:WFT  2018-05-22T00:00:00Z
# 28   local-authority-eng:TAW  2018-05-22T00:00:00Z
# 29   local-authority-eng:SHO  2018-05-22T00:00:00Z
# 30   local-authority-eng:BAS  2018-05-22T00:00:00Z
# 31   local-authority-eng:CHW  2018-05-22T00:00:00Z
# 32   local-authority-eng:SCA  2018-05-22T00:00:00Z
# 33   local-authority-eng:STO  2018-05-22T00:00:00Z
# 34   local-authority-eng:AYL  2018-05-22T00:00:00Z
# 35   local-authority-eng:SCE  2018-05-22T00:00:00Z
# 36   local-authority-eng:SLA  2018-05-22T00:00:00Z
# 37   local-authority-eng:BRM  2018-05-22T00:00:00Z
# 38   local-authority-eng:BNH  2018-05-22T00:00:00Z
# 39   local-authority-eng:CHR  2018-05-22T00:00:00Z
# 40   local-authority-eng:HUN  2018-05-22T00:00:00Z
# 41   local-authority-eng:KIR  2019-11-30T00:00:00Z
# 42   local-authority-eng:SEV  2019-12-01T00:00:00Z
# 43   local-authority-eng:BNH  2019-12-01T00:00:00Z
# 44   local-authority-eng:HUN  2019-12-14T00:00:00Z
# 45   local-authority-eng:HAL  2019-12-14T00:00:00Z
# 46   local-authority-eng:LCR  2020-03-10T00:00:00Z
# 47   local-authority-eng:LCR  2020-03-10T00:00:00Z
# 48   local-authority-eng:BUC  2021-08-26T00:00:00Z
# 49  local-authority-eng:WNUA  2021-08-26T00:00:00Z
# 50   local-authority-eng:BAN  2023-06-28T13:13:00Z
# 51   local-authority-eng:SUF  2023-09-13T00:00:00Z
#
#                               source  start_date
# 0   59748eb2bbe6634a99620f87acaf937e  2017-12-31
# 1   f92ceb2080500b1b68f7d4b33ceadedc  2017-12-21
# 2   f7721c61cb8732bf0fcad7083400d972
# 3   efb9c28a1591def1700ee912bb07bfe1
# 4   0787bb89a3ec6994493219b2c8551daa
# 5   07c446af20f78efab3ba5ab35e1a77ef  2017-12-13
# 6   09de2780b40099bf37cd0828834dbb93  2017-12-01
# 7   09e319746177cd551d1ac5542bb0d622
# 8   e6d3bda67c7c5f30dd70846bb1f38267
# 9   e284fb7807bef3d01ff56ec43512d3cc  2017-12-13
# 10  dfd5727ea56bd55d125d1549252bd1dd  2017-12-21
# 11  dbe8b71c706701cca0884208a8d80fb5
# 12  109283e4076b92f9371c243e3650affe
# 13  d47594c8f153c4cac05b4364b3a26149
# 14  cc60df80bab95c0cb94dccd07c1df031  2017-12-31
# 15  1575b21021e555aca0bef6fe96cb7e62  2017-12-20
# 16  18e991fb3bc3f3bd4e4ff4e533cb8a47  2017-05-22
# 17  1c432167b746435b4e82e1df9fe8b303
# 18  1c61ea01584b98506be2f8c67ddbde59
# 19  201cb21f2201851d49996070a74e6e6b
# 20  ab8ff01dd8cb79270539c90fa508cec7  2017-12-19
# 21  00cefb6c38c198f2042381c9ad058eab  2017-12-31
# 22  a5a0b0f3088b3608f9494a5398a07ba7  2017-12-01
# 23  23c4663a3c0cb17127165b66a7de97ab  2017-12-31
# 24  a3c53e6598c2cbb25915672f2865e981
# 25  91c7c1fee3d7bfebc4883c9d3054e62d
# 26  8e667387d554661208a7e2353cdc212c
# 27  2a4dd9160dbf93aaea6fc92930bb07dd
# 28  8951f22f50a465d5effe3262cc8eb293  2017-12-08
# 29  78b65dee7bd2b7b24774db63055d8177  2017-12-08
# 30  754e8c5848095a0e735a9ea62b5223ef  2017-12-31
# 31  74eaac546e2ef7b2bf2332c1ef2d1bde
# 32  353b519b9c1d63b2ba9834b5c2724093
# 33  71a951151c9171d70889ffe0a1f32034  2017-12-18
# 34  359d1df91ed530741a69528d5ea7ecbe  2017-12-19
# 35  3957a42e827136a638f83c5ea38f518a  2017-12-18
# 36  636a1017e76e18d616223586bc3745e2
# 37  408fd70b3ef833a219c7ec10963a910e
# 38  415ccbd7eea4e566c5cc9673512ca6d8
# 39  510814fa002a24a68d9bf505db4bd5a8
# 40  500a240136eab168933c3c72d19384b5  2017-12-31
# 41  e7e4637fbdc66056a28692969854776c  2018-02-28
# 42  2945df73cd0c2e16eea06ab905aff656  2019-03-05
# 43  19beccc23fdbfa8d717d6f7d345bf13c
# 44  01452d93513b05f65ec1a84204c7b57e
# 45  4010918a952fa69d4ee6071bfe53ccbc  2018-11-06
# 46  4d9b46ce85aa741040eb3d5da299b9ed  2020-03-10
# 47  67b0b64057e8e29ca86422d4df5efffd  2020-03-10
# 48  69757e95c1b4df45ad4758df10374530
# 49  c58211a8f5e8cf293ed2aa89c6a98ef0
# 50  f5c97058b20912c6302d8747965c6c9f
# 51  2570ec34d354341efd3fa8bd20aa0646

# %% [markdown]
# # Recently Added endpoints with no start date
#
# A recently added edpoint should have a start date, either derived from the LPA documentation page or from the data.

# %%
recent_entry_cutoff= "2023-06-01"

sql = F"""
    select src.organisation, src.documentation_url,  src.start_date as start_date, src.end_date, ep.endpoint, ep.endpoint_url, ep.entry_date as entry_date
	from source src 
	inner join endpoint ep on ep.endpoint = src.endpoint
	and src.collection = "{collection}"
	and ep.entry_date >= "{recent_entry_cutoff}"
	and ep.start_date = ""
    and src.end_date = ""
    order by entry_date DESC, start_date DESC 
    """

query_datasette(sql)
# Out:
#                 organisation  \
# 0    local-authority-eng:EHA
# 1    local-authority-eng:NGM
# 2    local-authority-eng:GLA
# 3    local-authority-eng:EHE
# 4    local-authority-eng:HAM
# ..                       ...
# 173  local-authority-eng:BEN
# 174  local-authority-eng:BEX
# 175  local-authority-eng:BAR
# 176  local-authority-eng:BBD
# 177  local-authority-eng:BAN
#
#                                      documentation_url  start_date end_date  \
# 0    https://www.easthants.gov.uk/planning-services...  2023-07-07
# 1    https://www.opendatanottingham.org.uk/dataset....  2021-11-05
# 2    https://data.london.gov.uk/dataset/brownfield_...  2020-07-12
# 3    https://www.eastherts.gov.uk/planning-building...  2017-12-31
# 4    https://www.easthants.gov.uk/planning-services...
# ..                                                 ...         ...      ...
# 173  https://www.brent.gov.uk/planning-and-building...
# 174  https://www.bexley.gov.uk/services/planning-an...
# 175  https://www.barrowbc.gov.uk/residents/planning...
# 176  https://www.blackburn.gov.uk/planning/planning...
# 177
#
#                                               endpoint  \
# 0    57ab427342eab58168dce8bf1c03a2351b8ad46d17bd3f...
# 1    c883436d69d3f852a8225da903fda36aa29d86f9ca5c4f...
# 2    890c3ac73da82610fe1b7d444c8c89c92a7f368316e3c0...
# 3    97d36593114822252b12c5cef9cc4d8d324d07d317efae...
# 4    57ab427342eab58168dce8bf1c03a2351b8ad46d17bd3f...
# ..                                                 ...
# 173  2d4bee3ace07e537a3dc44610fd48fed3c629f69b70ff4...
# 174  06aee45c3ecbb755ddf3a2184a3858308163456238d88e...
# 175  c78c84a3bde8a5ea9bad3faa9e9a1146679975a454eb84...
# 176  c618cc6e158b44a78bcab28f07508182b8af75e818e075...
# 177  8440f35a3e42919f5e9c851e98d5445a3c418c8ac314f6...
#
#                                           endpoint_url            entry_date
# 0    https://www.easthants.gov.uk/media/6377/downlo...  2023-09-13T00:00:00Z
# 1    https://geoserver.nottinghamcity.gov.uk/openda...  2023-09-13T00:00:00Z
# 2    https://data.london.gov.uk/download/brownfield...  2023-09-13T00:00:00Z
# 3    https://www.eastherts.gov.uk/sites/default/fil...  2023-09-13T00:00:00Z
# 4    https://www.easthants.gov.uk/media/6377/downlo...  2023-09-13T00:00:00Z
# ..                                                 ...                   ...
# 173  https://legacy.brent.gov.uk/media/16420302/bro...  2023-07-04T07:07:30Z
# 174  https://www.bexley.gov.uk/sites/default/files/...  2023-07-04T07:07:30Z
# 175  https://www.barrowbc.gov.uk/_resources/assets/...  2023-07-04T07:07:29Z
# 176  https://blackburn-darwen.org.uk/wp-content/upl...  2023-07-04T07:07:29Z
# 177  https://www.basingstoke.gov.uk/content/page/72...  2023-06-28T13:13:00Z
#
# [178 rows x 7 columns]

# %% [markdown]
# # Inspect a single LPA
#
# You can use the query below to get a quick overview of what entries we have for a single LPA in the collection

# %%
organisation= "local-authority-eng:WIN"


sql = F"""
    select src.organisation, src.documentation_url,  src.start_date, src.end_date, ep.endpoint_url, ep.endpoint, ep.entry_date as ep_entry_date,  ep.start_date as ep_start_date, ep.end_date as ep_end_date, ep.plugin
	from source src 
	inner join endpoint ep on ep.endpoint = src.endpoint
	where src.organisation = "{organisation}"
    and src.collection = "{collection}"
    order by ep.entry_date
    """

endpoints = query_datasette(sql)

for i in range(len(endpoints)):
    print("Organisation: " + endpoints.loc[i, "organisation"])
    print("documentation_url: " + endpoints.loc[i, "documentation_url"])
    print("endpoint_url: " + endpoints.loc[i, "endpoint_url"])
    print("plugin:  ", endpoints.loc[i, "plugin"])
    print("ep_entry_date:", endpoints.loc[i, "ep_entry_date"])
    print("ep_start_date:", endpoints.loc[i, "ep_start_date"])
    print("ep_end_date:  ", endpoints.loc[i, "ep_end_date"])

    print("\n")

endpoints
# Out:
# Organisation: local-authority-eng:WIN
# documentation_url:
# endpoint_url: http://www.winchester.gov.uk/assets/attach/13774/Brownfield%20Land%20Register%202017.csv
# plugin:
# ep_entry_date: 2018-05-22T00:00:00Z
# ep_start_date:
# ep_end_date:   2019-12-15
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/13774/Brownfield%20Land%20Register%202017.csv
# plugin:
# ep_entry_date: 2019-12-15T00:00:00Z
# ep_start_date:
# ep_end_date:   2023-09-05
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/17460/Brownfield%20Register%202018.csv
# plugin:
# ep_entry_date: 2019-12-22T00:00:00Z
# ep_start_date:
# ep_end_date:
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/20504/Brownfield%20Land%20Register%202019.csv
# plugin:
# ep_entry_date: 2019-12-22T00:00:00Z
# ep_start_date:
# ep_end_date:   2023-09-05
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/monitoring-and-other-planning-documents/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/27576/Winchester-City-Council-Brownfield-Land-Register-2020.xlsm
# plugin:
# ep_entry_date: 2021-09-08T00:00:00Z
# ep_start_date: 2021-09-09
# ep_end_date:
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/monitoring-and-other-planning-documents/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/20504/Brownfield-Land-Register-2019.csv
# plugin:
# ep_entry_date: 2021-09-08T00:00:00Z
# ep_start_date: 2021-09-09
# ep_end_date:
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/monitoring-and-other-planning-documents/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/13774/Brownfield-Land-Register-2017.csv
# plugin:
# ep_entry_date: 2021-09-08T00:00:00Z
# ep_start_date: 2021-09-09
# ep_end_date:
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/monitoring-and-other-planning-documents/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/17460/Brownfield-Register-2018.csv
# plugin:
# ep_entry_date: 2021-09-08T00:00:00Z
# ep_start_date: 2021-09-09
# ep_end_date:
#
#
# Organisation: local-authority-eng:WIN
# documentation_url: https://www.winchester.gov.uk/planning-policy/monitoring-and-other-planning-documents/brownfield-land-register
# endpoint_url: https://www.winchester.gov.uk/assets/attach/31799/brownfield-sites.csv
# plugin:
# ep_entry_date: 2022-03-09T00:00:00Z
# ep_start_date:
# ep_end_date:
#               organisation                                  documentation_url  \
# 0  local-authority-eng:WIN
# 1  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 2  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 3  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 4  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 5  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 6  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 7  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
# 8  local-authority-eng:WIN  https://www.winchester.gov.uk/planning-policy/...
#
#    start_date    end_date                                       endpoint_url  \
# 0              2019-12-15  http://www.winchester.gov.uk/assets/attach/137...
# 1              2023-09-05  https://www.winchester.gov.uk/assets/attach/13...
# 2                          https://www.winchester.gov.uk/assets/attach/17...
# 3              2023-09-05  https://www.winchester.gov.uk/assets/attach/20...
# 4  2021-09-09              https://www.winchester.gov.uk/assets/attach/27...
# 5  2021-09-09              https://www.winchester.gov.uk/assets/attach/20...
# 6  2021-09-09              https://www.winchester.gov.uk/assets/attach/13...
# 7  2021-09-09              https://www.winchester.gov.uk/assets/attach/17...
# 8                          https://www.winchester.gov.uk/assets/attach/31...
#
#                                             endpoint         ep_entry_date  \
# 0  48b44cd7af3b861361c22a90c915c6c87a0c768531fd1b...  2018-05-22T00:00:00Z
# 1  6aa8f0e3cb4a35bc13f4dd8fb2803404a337bce31d6a04...  2019-12-15T00:00:00Z
# 2  12ca9bd2b912e5ac4336907c0c35a49f17898111daa195...  2019-12-22T00:00:00Z
# 3  8c72913acc099caaf84aa702308b5bb3e3ba45e29e20ff...  2019-12-22T00:00:00Z
# 4  a453584baba30a957648ae88a28d611a6a470f926e49f5...  2021-09-08T00:00:00Z
# 5  2258441ef147e834873d3dd74d148df7900f7182023cba...  2021-09-08T00:00:00Z
# 6  4166ed48929df5b851829e5e69fe144c1e4b9dd7f44764...  2021-09-08T00:00:00Z
# 7  b0e362766c44c934b9d7deae12b305d46fd686aaa75a25...  2021-09-08T00:00:00Z
# 8  7eaea234caf233fc53495f8558b73fee074666266a0ae6...  2022-03-09T00:00:00Z
#
#   ep_start_date ep_end_date plugin
# 0                2019-12-15
# 1                2023-09-05
# 2
# 3                2023-09-05
# 4    2021-09-09
# 5    2021-09-09
# 6    2021-09-09
# 7    2021-09-09
# 8

# %%
sql = F"""
    select src.organisation, src.documentation_url,  src.start_date, src.end_date, ep.endpoint_url, ep.endpoint, ep.entry_date,  ep.start_date, ep.end_date
	from source src 
	inner join endpoint ep on ep.endpoint = src.endpoint
	where src.collection = "{collection}"
    and organisation like "local-authority-eng:%"
    order by 1, 2
    """

query_datasette(sql)
# Out:
#                  organisation  \
# 0     local-authority-eng:ADU
# 1     local-authority-eng:ADU
# 2     local-authority-eng:ADU
# 3     local-authority-eng:ALL
# 4     local-authority-eng:ALL
# ...                       ...
# 1279  local-authority-eng:YOR
# 1280  local-authority-eng:YOR
# 1281  local-authority-eng:YOR
# 1282  local-authority-eng:YOR
# 1283  local-authority-eng:YOR
#
#                                       documentation_url  start_date  \
# 0     https://www.adur-worthing.gov.uk/planning-poli...
# 1     https://www.adur-worthing.gov.uk/planning-poli...  2019-12-17
# 2     https://www.adur-worthing.gov.uk/planning-poli...  2023-07-06
# 3     https://www.allerdale.gov.uk/en/planning-build...  2017-12-20
# 4     https://www.allerdale.gov.uk/en/planning-build...  2017-12-20
# ...                                                 ...         ...
# 1279
# 1280  https://data.yorkopendata.org/dataset/brownfie...
# 1281         https://www.york.gov.uk/BrownfieldRegister  2017-12-22
# 1282         https://www.york.gov.uk/BrownfieldRegister  2017-12-22
# 1283         https://www.york.gov.uk/BrownfieldRegister  2019-12-18
#
#         end_date                                       endpoint_url  \
# 0     2019-12-17  https://www.adur-worthing.gov.uk/media/media,1...
# 1     2023-08-09  https://www.adur-worthing.gov.uk/media/media,1...
# 2                 https://www.adur-worthing.gov.uk/media/Media,1...
# 3                 https://df4iy9syor5px.cloudfront.net/media/fil...
# 4     2019-11-25  https://www-cloudfront.allerdale.gov.uk/media/...
# ...          ...                                                ...
# 1279              https://opendata.arcgis.com/datasets/24e275a6e...
# 1280              https://data.yorkopendata.org/dataset/7b937604...
# 1281              https://data.yorkopendata.org/dataset/7b937604...
# 1282              https://data.yorkopendata.org/dataset/7b937604...
# 1283              https://data.yorkopendata.org/dataset/7b937604...
#
#                                                endpoint            entry_date  \
# 0     3106ba8d16954b9e21a902c13a49046a0b2d37e4a8135c...  2018-05-22T00:00:00Z
# 1     87f2583f9562c85268d236c150dcbb9da3b373fdb28dab...  2019-12-18T00:00:00Z
# 2     ea98ea4d156ee47ff09af98d96d09951395b58e66d8b5f...  2023-08-11T09:09:57Z
# 3     9c2e8adfd12b4f474e7d511580029d1e69d1e08a17e0cb...  2018-05-22T00:00:00Z
# 4     5a0fcb2fdbe9d6f407b554642ab661a897a02c7a9e068a...  2018-07-30T00:00:00Z
# ...                                                 ...                   ...
# 1279  425a3e0cf53ef4980e9c133f850a6e9e1a34cfd2e444e4...  2018-05-22T00:00:00Z
# 1280  0f78fc9d126414d17f07e90d637ae76d65cdb09319fc20...  2023-08-10T13:13:26Z
# 1281  ed8725acf5769b2dd2467dcab1783eebc46afcdd7718d6...  2019-12-01T00:00:00Z
# 1282  2fc9a0b88861aa02584f2b90292bff7e1ccba9d420ef08...  2019-12-01T00:00:00Z
# 1283  dba02d5050b14b47891a07a12ec7f59b65f5dbcfee8695...  2019-12-22T00:00:00Z
#
#       start_date    end_date
# 0                 2019-12-17
# 1     2019-12-17  2023-08-09
# 2
# 3     2017-12-20
# 4     2017-12-20  2019-11-25
# ...          ...         ...
# 1279
# 1280
# 1281  2017-12-22
# 1282  2017-12-22
# 1283  2019-12-18
#
# [1284 rows x 9 columns]

# %%
# LPAs that we have not updated

sql = F"""
    select organisation, strftime('%Y',ep.entry_date) as year, strftime('%m',ep.entry_date) as month 
	from source src 
	inner join endpoint ep on ep.endpoint = src.endpoint
	where src.collection = "{collection}" 
    and year = "{current_year}"
    order by 3 DESC
    """

query_datasette(sql)
# Out:
#                 organisation  year month
# 0    local-authority-eng:LIF  2023    10
# 1    local-authority-eng:GRT  2023    10
# 2    local-authority-eng:NGM  2023    09
# 3    local-authority-eng:DEB  2023    09
# 4    local-authority-eng:DST  2023    09
# ..                       ...   ...   ...
# 291  local-authority-eng:SRI  2023    07
# 292  local-authority-eng:SST  2023    07
# 293  local-authority-eng:STT  2023    07
# 294  local-authority-eng:TOB  2023    07
# 295  local-authority-eng:BAN  2023    06
#
# [296 rows x 3 columns]

# %%
sql = F"""
    select organisation, count(ep.endpoint) as count
	from source src 
	inner join endpoint ep on ep.endpoint = src.endpoint
	where src.collection = "{collection}" 
    and ep.end_date != ""
    group by 1
    having count > 1
    order by 2 desc
    """

query_datasette(sql)
# Out:
#                           organisation  count
# 0              local-authority-eng:BAR     11
# 1              local-authority-eng:TEI      7
# 2    national-park-authority:Q72617669      6
# 3              local-authority-eng:SRI      6
# 4              local-authority-eng:LEE      6
# ..                                 ...    ...
# 170            local-authority-eng:BAN      2
# 171            local-authority-eng:ASH      2
# 172            local-authority-eng:ASF      2
# 173            local-authority-eng:ARU      2
# 174            local-authority-eng:ADU      2
#
# [175 rows x 2 columns]

# %%
sql = F"""
    select organisation, ep.*, strftime('%Y',ep.entry_date) as year
    from source src 
	left outer join endpoint ep on ep.endpoint = src.endpoint
	where src.collection = "{collection}" 
    and ep.end_date != ""
    order by 1
    """

query_datasette(sql)
# Out:
#                           organisation    end_date  \
# 0    development-corporation:Q20648596  2023-08-09
# 1              local-authority-eng:ADU  2019-12-17
# 2              local-authority-eng:ADU  2023-08-09
# 3              local-authority-eng:ALL  2019-11-25
# 4              local-authority-eng:ARU  2023-08-09
# ..                                 ...         ...
# 576  national-park-authority:Q72617669  2023-09-05
# 577  national-park-authority:Q72617784  2020-05-08
# 578  national-park-authority:Q72617784  2020-05-08
# 579  national-park-authority:Q72617988  2019-12-14
# 580  national-park-authority:Q72617988  2020-03-18
#
#                                               endpoint  \
# 0    5d30aee8c82e775dd4be67dd417bf782b33de8522edc1e...
# 1    3106ba8d16954b9e21a902c13a49046a0b2d37e4a8135c...
# 2    87f2583f9562c85268d236c150dcbb9da3b373fdb28dab...
# 3    5a0fcb2fdbe9d6f407b554642ab661a897a02c7a9e068a...
# 4    421cc4d3b8a060560139bbcede1787693ad9fbb503f0a9...
# ..                                                 ...
# 576  81bf05fd3a01607072e23896ec4e61979e2f572828147f...
# 577  687aab26f2ffbf2738a0b3abf3f164d0795ce933decb32...
# 578  20d3494f78924f4f202612668ad78949b8fad0726890e2...
# 579  f88e661f7b1e5b3dde4af9bf69d323261dec7cfd81eebd...
# 580  d902f01382a8414cc026476de4dcfabbc0a64a7d7e0c8f...
#
#                                           endpoint_url            entry_date  \
# 0    https://www.london.gov.uk/sites/default/files/...  2018-07-05T00:00:00Z
# 1    https://www.adur-worthing.gov.uk/media/media,1...  2018-05-22T00:00:00Z
# 2    https://www.adur-worthing.gov.uk/media/media,1...  2019-12-18T00:00:00Z
# 3    https://www-cloudfront.allerdale.gov.uk/media/...  2018-07-30T00:00:00Z
# 4    https://www.arun.gov.uk/download.cfm?doc=docm9...  2018-05-22T00:00:00Z
# ..                                                 ...                   ...
# 576  https://www.northyorkmoors.org.uk/__data/asset...  2022-01-04T00:00:00Z
# 577  http://www.exmoor-nationalpark.gov.uk/__data/a...  2018-05-22T00:00:00Z
# 578  https://www.exmoor-nationalpark.gov.uk/__data/...  2019-12-14T00:00:00Z
# 579  http://www.peakdistrict.gov.uk/__data/assets/f...  2018-05-22T00:00:00Z
# 580  https://www.peakdistrict.gov.uk/__data/assets/...  2019-12-14T00:00:00Z
#
#     parameters plugin  start_date  year
# 0                      2017-12-31  2018
# 1                                  2018
# 2                      2019-12-17  2019
# 3                      2017-12-20  2018
# 4                                  2018
# ..         ...    ...         ...   ...
# 576                                2022
# 577                    2017-12-19  2018
# 578                                2019
# 579                    2017-12-18  2018
# 580                    2017-12-18  2019
#
# [581 rows x 9 columns]

# %%
http_sql = F"""
  select src.organisation, src.documentation_url, ep.* from source src
  inner join endpoint ep on src.endpoint = ep.endpoint
  where src.collection  = "{collection}"
  and src.organisation not in (SELECT organisation FROM {viewName})
  and src.organisation like "local-authority-eng%"
   and ep.end_date != ""
  order by src.organisation, ep.start_date DESC NULLS LAST
"""

df = query_datasette(http_sql)
df.to_csv('hitlist.csv', index=False)

df
# Out:
#                organisation  \
# 0   local-authority-eng:CAB
# 1   local-authority-eng:CHN
# 2   local-authority-eng:CHW
# 3   local-authority-eng:CRA
# 4   local-authority-eng:EDN
# ..                      ...
# 65  local-authority-eng:WLL
# 66  local-authority-eng:WLL
# 67  local-authority-eng:WLL
# 68  local-authority-eng:WSO
# 69  local-authority-eng:WYO
#
#                                     documentation_url    end_date  \
# 0   https://www.cambridge.gov.uk/brownfield-land-r...  2019-11-24
# 1                                                      2019-11-29
# 2   https://consult.cheshirewestandchester.gov.uk/...  2020-03-14
# 3   https://www.cravendc.gov.uk/planning/brownfiel...  2019-10-20
# 4   https://www.eden.gov.uk/planning-and-building/...  2019-11-25
# ..                                                ...         ...
# 65  https://go.walsall.gov.uk/planning/planning_po...  2023-09-05
# 66  https://go.walsall.gov.uk/planning/planning_po...  2023-09-05
# 67  https://go.walsall.gov.uk/planning/planning_po...  2023-09-05
# 68  https://www.westsomersetonline.gov.uk/Planning...  2019-03-31
# 69  https://www.wycombe.gov.uk/pages/Planning-and-...  2019-11-01
#
#                                              endpoint  \
# 0   2ef4e42d7e4d6124010ed891ecf89cc131f7f9098abbf6...
# 1   1f4daca5b252bd8ed2437f533c30c57937d63b45b92051...
# 2   197d1b990b5cc6ebfb194ff9d039de5a2b85af6b732e26...
# 3   cd11a0daec5ec86adae6f34ee831af06d1a32235466fa3...
# 4   d1eb92649597a50f2cf43c528c17c14414b595590c4468...
# ..                                                ...
# 65  7c9a93e427aef9a4e0ea799c9cdea1bb148fef8d6d750a...
# 66  86fe71308d7cc6075a6740cb5f79393241bebcfa17d36e...
# 67  bfdedb9b3291b4dfe9bbbef99548204071bd6eb5166832...
# 68  944cbf2c4ea26ced18bd14478f65611302d7e22883a238...
# 69  1234a961deb842fca9c1a660ca8d02ae26a8273341df8a...
#
#                                          endpoint_url            entry_date  \
# 0   https://www.cambridge.gov.uk/sites/default/fil...  2018-05-22T00:00:00Z
# 1   http://www.chiltern.gov.uk/media/11738/Chilter...  2018-05-22T00:00:00Z
# 2   https://consult.cheshirewestandchester.gov.uk/...  2019-12-08T00:00:00Z
# 3   https://www.cravendc.gov.uk/media/5414/brownfi...  2018-05-22T00:00:00Z
# 4   https://www.eden.gov.uk/media/4921/brownfield_...  2018-05-22T00:00:00Z
# ..                                                ...                   ...
# 65  https://go.walsall.gov.uk/Portals/0/Uploads/Pl...  2020-03-13T00:00:00Z
# 66  https://go.walsall.gov.uk/Portals/0/Uploads/Pl...  2019-12-15T00:00:00Z
# 67  https://go.walsall.gov.uk/Portals/0/Uploads/Pl...  2020-03-13T00:00:00Z
# 68  https://www.westsomersetonline.gov.uk/Docs/Bro...  2018-05-22T00:00:00Z
# 69  https://www.wycombe.gov.uk/uploads/public/docu...  2019-10-21T00:00:00Z
#
#    parameters plugin  start_date
# 0
# 1
# 2
# 3
# 4
# ..        ...    ...         ...
# 65                    2020-03-13
# 66                    2018-12-17
# 67
# 68                    2017-12-31
# 69
#
# [70 rows x 9 columns]

# %%
http_sql = F"""
  select distinct src.organisation from source src
  where src.collection  = "{collection}"
  and src.organisation not in (SELECT organisation FROM {viewName})
  and src.organisation like "local-authority-eng%"
  order by src.organisation
"""
df = query_datasette(http_sql)

print ("These organisations need checking")
df
# Out:
# These organisations need checking
#                 organisation
# 0    local-authority-eng:AYL
# 1    local-authority-eng:CAB
# 2    local-authority-eng:CAN
# 3    local-authority-eng:CHN
# 4    local-authority-eng:CHW
# 5    local-authority-eng:COR
# 6    local-authority-eng:CRA
# 7    local-authority-eng:DAV
# 8    local-authority-eng:EDN
# 9    local-authority-eng:EDO
# 10   local-authority-eng:ELI
# 11   local-authority-eng:FOR
# 12   local-authority-eng:HAE
# 13   local-authority-eng:HAG
# 14   local-authority-eng:KET
# 15   local-authority-eng:LCE
# 16   local-authority-eng:LCR
# 17   local-authority-eng:LIC
# 18   local-authority-eng:LND
# 19   local-authority-eng:MEN
# 20   local-authority-eng:NDO
# 21   local-authority-eng:NNO
# 22  local-authority-eng:NNUA
# 23   local-authority-eng:NOR
# 24   local-authority-eng:NUN
# 25   local-authority-eng:POL
# 26   local-authority-eng:PUR
# 27   local-authority-eng:RIH
# 28   local-authority-eng:RYE
# 29   local-authority-eng:SBU
# 30   local-authority-eng:SCE
# 31   local-authority-eng:SED
# 32   local-authority-eng:SEG
# 33   local-authority-eng:SEL
# 34   local-authority-eng:SKE
# 35   local-authority-eng:SLA
# 36   local-authority-eng:SLF
# 37   local-authority-eng:SNR
# 38   local-authority-eng:SSO
# 39   local-authority-eng:STA
# 40   local-authority-eng:STN
# 41   local-authority-eng:STV
# 42   local-authority-eng:SUF
# 43   local-authority-eng:SWT
# 44   local-authority-eng:TAU
# 45   local-authority-eng:TEW
# 46   local-authority-eng:THA
# 47   local-authority-eng:WAV
# 48   local-authority-eng:WBK
# 49   local-authority-eng:WDE
# 50   local-authority-eng:WDO
# 51   local-authority-eng:WEA
# 52   local-authority-eng:WEL
# 53   local-authority-eng:WFT
# 54   local-authority-eng:WIL
# 55   local-authority-eng:WIN
# 56   local-authority-eng:WLL
# 57   local-authority-eng:WSO
# 58   local-authority-eng:WYO
