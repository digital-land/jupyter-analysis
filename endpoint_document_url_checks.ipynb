# %%
import urllib
import pandas as pd

# %% [markdown]
# # Selecting Endpoints of Primary Datasets **without** Documentation Url
# The following query selects rows of the endpoint table where:
# - The documentation_url **is** an empty character string or null
# - The endpoint is one of the eight primary datasets
# - The end date is null (endpoint has not been ended)
# - The organisation field begins with "local-authority-eng:" (only selecting LPAs)
#
# The following pandas code then selects only the most recent endpoints, per organisation-dataset group.

# %%
datasette_url = "https://datasette.planning.data.gov.uk/"
def grab_no_doc_endpoints():
    global endpoints_with_no_doc_url  
    params = urllib.parse.urlencode({
        "sql": f"""
        SELECT 
            s.organisation, 
            sp.pipeline AS "pipeline/dataset", 
            e.endpoint_url, 
            s.documentation_url,
            s.entry_date,
            e.endpoint
        FROM 
            endpoint e
            INNER JOIN source s on e.endpoint = s.endpoint
            INNER JOIN source_pipeline sp on s.source = sp.source
            INNER JOIN organisation o ON 
        WHERE 
            (documentation_url == "" OR documentation_url IS NULL)
            AND (sp.pipeline IN (
                'article-4-direction-area',
                'article-4-direction',
                'conservation-area',
                'conservation-area-document',
                'listed-building-outline',
                'tree-preservation-zone',
                'tree-preservation-order',
                'tree')) 
            AND (s.end_date == "" OR s.end_date IS NULL)
            AND s.organisation LIKE "local-authority%"
        """,
        "_size": "max"
    })
    
    url = f"{datasette_url}digital-land.csv?{params}"
    endpoints_with_no_doc_url = pd.read_csv(url)
    return endpoints_with_no_doc_url

df = grab_no_doc_endpoints()
df['entry_date'] = pd.to_datetime(df['entry_date'])

# Group by 'organisation' and 'pipeline/dataset', then find the index of the most recent entry
idx = df.groupby(['organisation', 'pipeline/dataset'])['entry_date'].idxmax()

# Use the index to select the rows
endpoints_with_no_doc_url = df.loc[idx].reset_index()

#Drop index field
endpoints_with_no_doc_url = endpoints_with_no_doc_url.drop("index", axis=1)

endpoints_with_no_doc_url
# Out:
#                organisation          pipeline/dataset  \
# 0   local-authority-eng:BDG  article-4-direction-area
# 1   local-authority-eng:BDG         conservation-area
# 2   local-authority-eng:BDG   listed-building-outline
# 3   local-authority-eng:BIR  article-4-direction-area
# 4   local-authority-eng:BIR         conservation-area
# 5   local-authority-eng:BUC  article-4-direction-area
# 6   local-authority-eng:BUC         conservation-area
# 7   local-authority-eng:BUC   listed-building-outline
# 8   local-authority-eng:BUC                      tree
# 9   local-authority-eng:BUC    tree-preservation-zone
# 10  local-authority-eng:DOV       article-4-direction
# 11  local-authority-eng:DOV  article-4-direction-area
# 12  local-authority-eng:DOV   tree-preservation-order
# 13  local-authority-eng:EPS         conservation-area
# 14  local-authority-eng:EPS   listed-building-outline
# 15  local-authority-eng:ESK         conservation-area
# 16  local-authority-eng:GAT                      tree
# 17  local-authority-eng:GAT    tree-preservation-zone
# 18  local-authority-eng:GRY    tree-preservation-zone
# 19  local-authority-eng:NET                      tree
# 20  local-authority-eng:NET   tree-preservation-order
# 21  local-authority-eng:SWK       article-4-direction
# 22  local-authority-eng:SWK         conservation-area
# 23  local-authority-eng:SWK   listed-building-outline
# 24  local-authority-eng:SWK   tree-preservation-order
# 25  local-authority-eng:SWK    tree-preservation-zone
#
#                                          endpoint_url  documentation_url  \
# 0   https://services3.arcgis.com/lCzPKKaGs7lhrnrV/...                NaN
# 1   https://services3.arcgis.com/lCzPKKaGs7lhrnrV/...                NaN
# 2   https://services3.arcgis.com/lCzPKKaGs7lhrnrV/...                NaN
# 8   921954ef5241801cd3c199ace4f9e551e6214ab34ff66d...
# 9   76a55253fac858f0ed7daf595191cbbc37f7493f35b38e...
# 10  03b17776d0e7707bdb98768bdcac82cf7d01595a353603...
# 11  701a969f68db2fb8bae189534a1f32bb1cc5e357a3f67a...
# 12  ff199b1dc647436cb33b44f767c27b282ac993f2c0b8b8...
# 13  9247d952f3d1a3ad3ca513bb5c0169ffb7bd9b54c285fb...
# 14  b64e3b0edc13c75c0a21a459c13c7c9c6eb89e0785885c...
# 15  5e85fc70a1b7cd17df9be2506d3506459e52c456bbe219...
# 16  124dc88d5839fa63b5802abe2847e3bf959b3052a3dcd1...
# 17  588e4f0dfb29a0181a302b8c9785abb24d881ae8cab122...
# 18  9240f1ca39efc8880a909f92bd0613c9dbd6cf1990217a...
# 19  84f6228e842a4a410c41ada01dcb50eb5e8a5a8f8299ef...
# 20  84f6228e842a4a410c41ada01dcb50eb5e8a5a8f8299ef...
# 21  7b50969a85c19aec02a07248a5aabde97ea0fe835ca5e6...
# 22  31842426b0b97c7ad8288a510c4b137055c7fb90ad3003...
# 23  7d33d185db7a5ba469da8f9e1d8d04a09f1a3565027128...
# 24  810751d8f4697034343d69ea0b5f365362089c9d2c083a...
# 25  810751d8f4697034343d69ea0b5f365362089c9d2c083a...

# %%
download = input("Do you want to download the table? (yes/no): ")

if download.lower() == "yes":
    endpoints_with_no_doc_url.to_csv("endpoints_with_no_doc_url.csv", index=False)
    print("Query result downloaded as 'endpoints_with_no_doc_url.csv'")
# Out:
# Do you want to download the table? (yes/no):  no

# %% [markdown]
# # Selecting Endpoints of Primary Datasets **with** Documentation Urls
# The following query selects rows of the endpoint table where:
# - The documentation_url is **not** an empty character string or null
# - The endpoint is one of the eight primary datasets
# - The end date is an empty string or null (endpoint has not been ended)
# - The organisation field begins with "local-authority-eng:" (only selecting LPAs)
#
# The following pandas code then selects only the most recent endpoints, per organisation-dataset group.

# %%
def grab_endpoints_with_docs():
    global endpoints_with_doc_url  
    params = urllib.parse.urlencode({
        "sql": f"""
        SELECT 
            s.organisation, 
            sp.pipeline AS 'pipeline/dataset', 
            e.endpoint_url, 
            s.documentation_url,
            s.entry_date,
            e.endpoint
        FROM 
            endpoint e
            INNER JOIN source s on e.endpoint = s.endpoint
            INNER JOIN source_pipeline sp on s.source = sp.source
        WHERE 
            (documentation_url != "" AND documentation_url IS NOT NULL)
            AND (sp.pipeline IN (
                'article-4-direction-area',
                'article-4-direction',
                'conservation-area',
                'conservation-area-document',
                'listed-building-outline',
                'tree-preservation-zone',
                'tree-preservation-order',
                'tree')) 
            AND (s.end_date == "" OR s.end_date IS NULL)
            AND s.organisation LIKE "local-authority%"
        """,
        "_size": "max"
    })
    
    url = f"{datasette_url}digital-land.csv?{params}"
    endpoints_with_doc_url = pd.read_csv(url)
    return endpoints_with_doc_url

df = grab_endpoints_with_docs()

df['entry_date'] = pd.to_datetime(df['entry_date'])

# Group by 'organisation' and 'pipeline/dataset', then find the index of the most recent entry
idx = df.groupby(['organisation', 'pipeline/dataset'])['entry_date'].idxmax()

# Use the index to select the rows
endpoints_with_doc_url = df.loc[idx].reset_index()

#Drop index field
endpoints_with_doc_url = endpoints_with_doc_url.drop("index", axis=1)

endpoints_with_doc_url
# Out:
#                 organisation          pipeline/dataset  \
# 0    local-authority-eng:BAB         conservation-area
# 1    local-authority-eng:BAR         conservation-area
# 2    local-authority-eng:BNE       article-4-direction
# 3    local-authority-eng:BNE  article-4-direction-area
# 4    local-authority-eng:BNE         conservation-area
# ..                       ...                       ...
# 119  local-authority-eng:WBK    tree-preservation-zone
# 120  local-authority-eng:WNM         conservation-area
# 121  local-authority-eng:WOX         conservation-area
# 122  local-authority-eng:WYO         conservation-area
# 123  local-authority-eng:YOR         conservation-area
#
#                                           endpoint_url  \
# 0    http://inspire.misoportal.com/geoserver/baberg...
# 1    https://webgis1.barrowbc.gov.uk/inspire/wfs?se...
# 2    https://open.barnet.gov.uk/download/2ylny/z7y/...
# 3    https://open.barnet.gov.uk/download/e5l77/dhv/...
# 4    https://open.barnet.gov.uk/download/20yo8/c6n/...
# ..                                                 ...
# 119  https://gis.westberks.gov.uk/server/rest/servi...
# 120  https://geodata.rbwm.gov.uk/geoserver/wminspir...
# 121  http://inspire.misoportal.com/geoserver/west_o...
# 122  https://inspire.wycombe.gov.uk/getows.ashx?Map...
# 123  http://data.cyc.opendata.arcgis.com/datasets/3...
#
#                                      documentation_url  \
# 0    https://data.gov.uk/dataset/c782a0de-ef2f-4c6d...
# 1    https://data.gov.uk/dataset/b62d9315-b1d5-455c...
# 2    https://open.barnet.gov.uk/dataset/2ylny/artic...
# 3    https://open.barnet.gov.uk/dataset/e5l77/artic...
# 4    https://open.barnet.gov.uk/dataset/20yo8/conse...
# ..                                                 ...
# 119  https://www.westberks.gov.uk/planning-data-tre...
# 120  https://data.gov.uk/dataset/739ffcb2-54ba-49a0...
# 121  https://data.gov.uk/dataset/8e05f77a-2fd3-4c20...
# 122  https://data.gov.uk/dataset/64f0dd17-3ec6-4099...
# 123  https://data.gov.uk/dataset/befc8b34-a954-4527...
#
#                    entry_date  \
# 0   2020-11-29 12:18:40+00:00
# 1   2020-11-29 12:18:40+00:00
# 2   2023-12-18 00:00:00+00:00
# 3   2023-12-18 00:00:00+00:00
# 4   2023-11-06 00:00:00+00:00
# ..                        ...
# 119 2024-01-24 00:00:00+00:00
# 120 2020-11-29 12:18:40+00:00
# 121 2020-11-29 12:18:40+00:00
# 122 2020-11-29 12:18:40+00:00
# 123 2020-11-29 12:18:40+00:00
#
#                                               endpoint
# 0    e6a63c92987299ca1409660135ab597f51b13f8c050421...
# 1    91ab6be088bfb215edd320eee06ad41dc291b8a20c21d5...
# 2    4d69e04b32ecfa83f9c17f1fed6f13a94dc8c839607dd8...
# 3    d4c09389082ca55e33cf532eb045ea7eb9dc447a24547f...
# 4    1cafec4102c43a9e95f54bd36453240251c7741d7d15de...
# ..                                                 ...
# 119  c3b09959756401a0a1e9a3b75e34fe60dcf48c91b3b1b7...
# 120  5f4c5116955fcf2d4398988c3edfcd12175cd371f9bacb...
# 121  e2c7984b3b5f32e6420e243fef483d4d37b307f2ad84f4...
# 122  c2aa5fe7f3050a4a2b4f5114bed6e5d6b4b492297e4d7e...
# 123  c89258d2677ecee8125a4258ebc3d7cc794d21bd626a33...
#
# [124 rows x 6 columns]

# %%
download = input("Do you want to download the table? (yes/no): ")

if download.lower() == "yes":
    endpoints_with_doc_url.to_csv("endpoints_with_doc_url.csv", index=False)
    print("Query result downloaded as 'endpoints_with_doc_url.csv'")
# Out:
# Do you want to download the table? (yes/no):  no
