# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# conservation_area lookup file
data = pd.read_csv('lookup.csv')

# %%
data.head()
# Out:
#               prefix resource  endpoint  entry-number  \
# 0  conservation-area      NaN       NaN           NaN
# 1  conservation-area      NaN       NaN           NaN
# 2  conservation-area      NaN       NaN           NaN
# 3  conservation-area      NaN       NaN           NaN
# 4  conservation-area      NaN       NaN           NaN
#
#                      organisation reference    entity  entry-date  start-date  \
# 0  government-organisation:PB1164      5080  44000001         NaN         NaN
# 1  government-organisation:PB1164      5071  44000002         NaN         NaN
# 2  government-organisation:PB1164      5074  44000003         NaN         NaN
# 3  government-organisation:PB1164      5075  44000004         NaN         NaN
# 4  government-organisation:PB1164      5078  44000005         NaN         NaN
#
#    end-date
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
data = data.dropna(subset=['entity', 'organisation'])

data['entity'] = pd.to_numeric(data['entity'])

data = data.sort_values(by=['organisation', 'entity']).reset_index(drop=True)

# increment_id tracks when the organisation or non-consecutive entity changes
data['increment_id'] = (data['organisation'] != data['organisation'].shift(1)) | \
                       (data['prefix'] != data['prefix'].shift(1)) | \
                       ((data['entity'] - data['entity'].shift(1)) != 1)


# Cumulatively sum the 'increment_id' to get the unique range IDs
data['increment_id'] = data['increment_id'].cumsum()

# Group by organisation and the 'increment_id' to calculate min and max entities for each range
entity_ranges = data.groupby(['prefix','organisation', 'increment_id']).agg(
    min_entity=('entity', 'min'),
    max_entity=('entity', 'max')
).reset_index()

entity_ranges = entity_ranges.drop(columns=['increment_id'])

entity_ranges
# Out:
#                                prefix                      organisation  \
# 0                   conservation-area  development-corporation:Q6670544
# 1                   conservation-area  development-corporation:Q6670544
# 2                   conservation-area  development-corporation:Q6670544
# 3                   conservation-area     government-organisation:D1342
# 4                   conservation-area     government-organisation:D1342
# ...                               ...                               ...
# 1427       conservation-area-document               local-authority:ROH
# 1428       conservation-area-document               local-authority:ROS
# 1429       conservation-area-document               local-authority:SAL
# 1430       conservation-area-document               local-authority:WRL
# 1431  conservation-area-document-type     government-organisation:D1342
#
#       min_entity  max_entity
# 0       44003422    44003423
# 1       44006543    44006543
# 2       44009061    44009061
# 3       44010311    44010413
# 4       44010623    44012250
# ...          ...         ...
# 1427     6300214     6300229
# 1428     6300062     6300095
# 1429     6300000     6300044
# 1430     6303118     6303261
# 1431     4210000     4210003
#
# [1432 rows x 4 columns]

# %%
entity_ranges.to_csv('entity_ranges_pandas_approach.csv', index=False)

# %%
# ======== RETURNS: DATASET, ORGANISATION, MIN and MAX ENTITY RANGE
def find_organization_entity_ranges(df):
    """
    Find the overall entity ranges for each organization
    
   
    """
    # Group  organization, find  overall min and max 
    org_ranges = df.groupby(['prefix','organisation']).agg({
        'min_entity': 'min',
        'max_entity': 'max'
    }).reset_index()

    org_ranges.rename(columns={"min_entity": "entity-minimum", "max_entity": "entity-maximum"}, inplace=True)

    
    org_ranges = org_ranges.sort_values('entity-minimum')
    org_ranges['range_span'] = org_ranges['entity-maximum'] - org_ranges['entity-minimum'] +1
    
    return org_ranges

# Load entity_ranges csv from above cell
entity_ranges = pd.read_csv('entity_ranges_pandas_approach.csv')


final_org_ranges = find_organization_entity_ranges(entity_ranges)

print("Organization Entity Ranges:")
print("-" * 50)
for _, row in final_org_ranges.iterrows():
    print(f"Organisation: {row['organisation']}")
    print(f"First Entity: {row['entity-minimum']}")
    print(f"Last Entity:  {row['entity-maximum']}")
    print("-" * 50)


final_org_ranges.to_csv('organization_final_entity_ranges.csv', index=False)




final_org_ranges
# Out:
# Organization Entity Ranges:
# --------------------------------------------------
# Organisation: government-organisation:D1342
# First Entity: 4210000
# Last Entity:  4210003
# --------------------------------------------------
# Organisation: local-authority:SAL
# First Entity: 6300000
# Last Entity:  6300044
# --------------------------------------------------
# Organisation: local-authority:NLN
# First Entity: 6300045
# Last Entity:  6300061
# --------------------------------------------------
# Organisation: local-authority:ROS
# First Entity: 6300062
# Last Entity:  6300095
# --------------------------------------------------
# Organisation: local-authority:CMD
# First Entity: 6300096
# Last Entity:  6300157
# --------------------------------------------------
# Organisation: local-authority:PTE
# First Entity: 6300158
# Last Entity:  6300213
# --------------------------------------------------
# Organisation: local-authority:ROH
# First Entity: 6300214
# Last Entity:  6300229
# --------------------------------------------------
# Organisation: local-authority:CAS
# First Entity: 6300230
# Last Entity:  6300231
# --------------------------------------------------
# Organisation: government-organisation:D1342
# First Entity: 6300232
# Last Entity:  6303117
# --------------------------------------------------
# Organisation: local-authority:BIR
# First Entity: 6300438
# Last Entity:  6300479
# --------------------------------------------------
# Organisation: local-authority:BST
# First Entity: 6300480
# Last Entity:  6300513
# --------------------------------------------------
# Organisation: local-authority:WRL
# First Entity: 6303118
# Last Entity:  6303261
# --------------------------------------------------
# Organisation: local-authority:BNE
# First Entity: 6303262
# Last Entity:  6303301
# --------------------------------------------------
# Organisation: local-authority:PLY
# First Entity: 6303302
# Last Entity:  6303316
# --------------------------------------------------
# Organisation: local-authority:SAL
# First Entity: 44000001
# Last Entity:  44010124
# --------------------------------------------------
# Organisation: government-organisation:PB1164
# First Entity: 44000001
# Last Entity:  44009885
# --------------------------------------------------
# Organisation: local-authority:BRT
# First Entity: 44000071
# Last Entity:  44007977
# --------------------------------------------------
# Organisation: national-park-authority:Q72617988
# First Entity: 44000191
# Last Entity:  44007439
# --------------------------------------------------
# Organisation: local-authority:CON
# First Entity: 44000193
# Last Entity:  44009597
# --------------------------------------------------
# Organisation: local-authority:HAL
# First Entity: 44000380
# Last Entity:  44007963
# --------------------------------------------------
# Organisation: local-authority:NET
# First Entity: 44000537
# Last Entity:  44002959
# --------------------------------------------------
# Organisation: local-authority:OLD
# First Entity: 44000549
# Last Entity:  44012329
# --------------------------------------------------
# Organisation: local-authority:LBH
# First Entity: 44000550
# Last Entity:  44012345
# --------------------------------------------------
# Organisation: local-authority:RDB
# First Entity: 44000591
# Last Entity:  44009051
# --------------------------------------------------
# Organisation: local-authority:WRL
# First Entity: 44000663
# Last Entity:  44012276
# --------------------------------------------------
# Organisation: local-authority:TEW
# First Entity: 44000701
# Last Entity:  44005233
# --------------------------------------------------
# Organisation: local-authority:WBK
# First Entity: 44000713
# Last Entity:  44010140
# --------------------------------------------------
# Organisation: local-authority:CAR
# First Entity: 44000997
# Last Entity:  44009145
# --------------------------------------------------
# Organisation: local-authority:CRY
# First Entity: 44001014
# Last Entity:  44008883
# --------------------------------------------------
# Organisation: local-authority:WND
# First Entity: 44001043
# Last Entity:  44009103
# --------------------------------------------------
# Organisation: local-authority:PTE
# First Entity: 44001130
# Last Entity:  44005183
# --------------------------------------------------
# Organisation: local-authority:NLN
# First Entity: 44001414
# Last Entity:  44005181
# --------------------------------------------------
# Organisation: local-authority:SOS
# First Entity: 44001617
# Last Entity:  44007973
# --------------------------------------------------
# Organisation: local-authority:MAL
# First Entity: 44001675
# Last Entity:  44007830
# --------------------------------------------------
# Organisation: local-authority:GED
# First Entity: 44001676
# Last Entity:  44006734
# --------------------------------------------------
# Organisation: local-authority:EPS
# First Entity: 44001788
# Last Entity:  44009884
# --------------------------------------------------
# Organisation: local-authority:CAT
# First Entity: 44001792
# Last Entity:  44010079
# --------------------------------------------------
# Organisation: local-authority:BRC
# First Entity: 44001799
# Last Entity:  44007965
# --------------------------------------------------
# Organisation: local-authority:MOL
# First Entity: 44001802
# Last Entity:  44008707
# --------------------------------------------------
# Organisation: local-authority:WOX
# First Entity: 44001831
# Last Entity:  44012336
# --------------------------------------------------
# Organisation: local-authority:WAE
# First Entity: 44001859
# Last Entity:  44008655
# --------------------------------------------------
# Organisation: local-authority:STH
# First Entity: 44001995
# Last Entity:  44008198
# --------------------------------------------------
# Organisation: local-authority:EAL
# First Entity: 44002323
# Last Entity:  44008920
# --------------------------------------------------
# Organisation: local-authority:SWK
# First Entity: 44002349
# Last Entity:  44010269
# --------------------------------------------------
# Organisation: local-authority:KTT
# First Entity: 44002387
# Last Entity:  44009068
# --------------------------------------------------
# Organisation: local-authority:BNE
# First Entity: 44002411
# Last Entity:  44006529
# --------------------------------------------------
# Organisation: local-authority:GLA
# First Entity: 44002411
# Last Entity:  44006529
# --------------------------------------------------
# Organisation: local-authority:HIL
# First Entity: 44002425
# Last Entity:  44009093
# --------------------------------------------------
# Organisation: local-authority:RIC
# First Entity: 44002450
# Last Entity:  44009087
# --------------------------------------------------
# Organisation: local-authority:LND
# First Entity: 44002494
# Last Entity:  44012304
# --------------------------------------------------
# Organisation: local-authority:BEX
# First Entity: 44002792
# Last Entity:  44009013
# --------------------------------------------------
# Organisation: local-authority:BRY
# First Entity: 44002813
# Last Entity:  44009101
# --------------------------------------------------
# Organisation: local-authority:WSM
# First Entity: 44002850
# Last Entity:  44009069
# --------------------------------------------------
# Organisation: local-authority:HAV
# First Entity: 44002904
# Last Entity:  44002914
# --------------------------------------------------
# Organisation: local-authority:BDG
# First Entity: 44002915
# Last Entity:  44002918
# --------------------------------------------------
# Organisation: local-authority:CLD
# First Entity: 44003007
# Last Entity:  44007924
# --------------------------------------------------
# Organisation: local-authority:COT
# First Entity: 44003142
# Last Entity:  44007975
# --------------------------------------------------
# Organisation: local-authority:SEG
# First Entity: 44003388
# Last Entity:  44007872
# --------------------------------------------------
# Organisation: local-authority:HNS
# First Entity: 44003402
# Last Entity:  44009075
# --------------------------------------------------
# Organisation: local-authority:NWM
# First Entity: 44003415
# Last Entity:  44003421
# --------------------------------------------------
# Organisation: development-corporation:Q6670544
# First Entity: 44003422
# Last Entity:  44009061
# --------------------------------------------------
# Organisation: local-authority:WFT
# First Entity: 44003424
# Last Entity:  44008877
# --------------------------------------------------
# Organisation: local-authority:TWH
# First Entity: 44003435
# Last Entity:  44010588
# --------------------------------------------------
# Organisation: local-authority:HOR
# First Entity: 44003564
# Last Entity:  44010308
# --------------------------------------------------
# Organisation: local-authority:NED
# First Entity: 44003647
# Last Entity:  44008600
# --------------------------------------------------
# Organisation: local-authority:SLF
# First Entity: 44004019
# Last Entity:  44008711
# --------------------------------------------------
# Organisation: local-authority:SOX
# First Entity: 44004350
# Last Entity:  44009141
# --------------------------------------------------
# Organisation: local-authority:VAL
# First Entity: 44004423
# Last Entity:  44009161
# --------------------------------------------------
# Organisation: local-authority:SHN
# First Entity: 44004834
# Last Entity:  44007679
# --------------------------------------------------
# Organisation: local-authority:SKP
# First Entity: 44004838
# Last Entity:  44004874
# --------------------------------------------------
# Organisation: local-authority:BRD
# First Entity: 44004967
# Last Entity:  44005025
# --------------------------------------------------
# Organisation: local-authority:YOR
# First Entity: 44005080
# Last Entity:  44009138
# --------------------------------------------------
# Organisation: local-authority:MRT
# First Entity: 44005395
# Last Entity:  44009014
# --------------------------------------------------
# Organisation: local-authority:BAB
# First Entity: 44005968
# Last Entity:  44008684
# --------------------------------------------------
# Organisation: local-authority:HCK
# First Entity: 44006227
# Last Entity:  44009089
# --------------------------------------------------
# Organisation: local-authority:BUC
# First Entity: 44006432
# Last Entity:  44010585
# --------------------------------------------------
# Organisation: local-authority:LCE
# First Entity: 44006443
# Last Entity:  44010271
# --------------------------------------------------
# Organisation: local-authority:TRF
# First Entity: 44006481
# Last Entity:  44010414
# --------------------------------------------------
# Organisation: local-authority:SHF
# First Entity: 44006554
# Last Entity:  44009159
# --------------------------------------------------
# Organisation: local-authority:KWL
# First Entity: 44007851
# Last Entity:  44007865
# --------------------------------------------------
# Organisation: local-authority:WNM
# First Entity: 44007873
# Last Entity:  44007873
# --------------------------------------------------
# Organisation: local-authority:ESK
# First Entity: 44007891
# Last Entity:  44007901
# --------------------------------------------------
# Organisation: local-authority:NOW
# First Entity: 44007902
# Last Entity:  44007918
# --------------------------------------------------
# Organisation: local-authority:PUR
# First Entity: 44007978
# Last Entity:  44008103
# --------------------------------------------------
# Organisation: local-authority:DUR
# First Entity: 44008104
# Last Entity:  44008196
# --------------------------------------------------
# Organisation: local-authority:DUD
# First Entity: 44008197
# Last Entity:  44008246
# --------------------------------------------------
# Organisation: local-authority:ROC
# First Entity: 44008337
# Last Entity:  44008346
# --------------------------------------------------
# Organisation: local-authority:HMF
# First Entity: 44008347
# Last Entity:  44012344
# --------------------------------------------------
# Organisation: local-authority:KEC
# First Entity: 44008380
# Last Entity:  44008967
# --------------------------------------------------
# Organisation: local-authority:NDO
# First Entity: 44008601
# Last Entity:  44012343
# --------------------------------------------------
# Organisation: local-authority:ISL
# First Entity: 44008712
# Last Entity:  44009007
# --------------------------------------------------
# Organisation: local-authority:LEW
# First Entity: 44008713
# Last Entity:  44009097
# --------------------------------------------------
# Organisation: local-authority:ENF
# First Entity: 44008714
# Last Entity:  44010295
# --------------------------------------------------
# Organisation: local-authority:HRY
# First Entity: 44008721
# Last Entity:  44009091
# --------------------------------------------------
# Organisation: local-authority:BEN
# First Entity: 44008733
# Last Entity:  44008910
# --------------------------------------------------
# Organisation: local-authority:HRW
# First Entity: 44008756
# Last Entity:  44009102
# --------------------------------------------------
# Organisation: local-authority:STN
# First Entity: 44008764
# Last Entity:  44008872
# --------------------------------------------------
# Organisation: local-authority:GRE
# First Entity: 44008815
# Last Entity:  44009056
# --------------------------------------------------
# Organisation: local-authority:CHI
# First Entity: 44009104
# Last Entity:  44009107
# --------------------------------------------------
# Organisation: local-authority:BOL
# First Entity: 44009108
# Last Entity:  44012320
# --------------------------------------------------
# Organisation: local-authority:CMD
# First Entity: 44009614
# Last Entity:  44009885
# --------------------------------------------------
# Organisation: local-authority:GLO
# First Entity: 44009664
# Last Entity:  44009677
# --------------------------------------------------
# Organisation: local-authority:GRY
# First Entity: 44009678
# Last Entity:  44009700
# --------------------------------------------------
# Organisation: local-authority:DOV
# First Entity: 44009701
# Last Entity:  44009803
# --------------------------------------------------
# Organisation: local-authority:MDW
# First Entity: 44009804
# Last Entity:  44009827
# --------------------------------------------------
# Organisation: local-authority:BIR
# First Entity: 44009828
# Last Entity:  44009856
# --------------------------------------------------
# Organisation: local-authority:GAT
# First Entity: 44009857
# Last Entity:  44010270
# --------------------------------------------------
# Organisation: local-authority:DNC
# First Entity: 44009886
# Last Entity:  44009931
# --------------------------------------------------
# Organisation: local-authority:ROS
# First Entity: 44010125
# Last Entity:  44010134
# --------------------------------------------------
# Organisation: local-authority:NSM
# First Entity: 44010141
# Last Entity:  44010179
# --------------------------------------------------
# Organisation: local-authority:ECA
# First Entity: 44010180
# Last Entity:  44010207
# --------------------------------------------------
# Organisation: local-authority:SAW
# First Entity: 44010208
# Last Entity:  44010216
# --------------------------------------------------
# Organisation: local-authority:ROH
# First Entity: 44010296
# Last Entity:  44010305
# --------------------------------------------------
# Organisation: local-authority:CAS
# First Entity: 44010309
# Last Entity:  44010310
# --------------------------------------------------
# Organisation: government-organisation:D1342
# First Entity: 44010311
# Last Entity:  44012250
# --------------------------------------------------
# Organisation: local-authority:BST
# First Entity: 44010589
# Last Entity:  44010622
# --------------------------------------------------
# Organisation: local-authority:PLY
# First Entity: 44012305
# Last Entity:  44012319
# --------------------------------------------------
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[20], line 37
#      33     print(f"Last Entity:  {row['entity-maximum']}")
#      34     print("-" * 50)
# ---> 37 final_org_ranges.to_csv('organization_final_entity_ranges.csv', index=False)
#      42 final_org_ranges
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'organization_final_entity_ranges.csv'

# %%
# ======== RETURNS: DATASET, ORGANISATION, MIN, MAX ENTITY RANGE, RANGE_SPAN and FILLED_SPACES

def find_organization_entity_ranges(df):
    """
    Find the overall entity ranges and calculate range span for each organization.
    """
    # Group prefix and organisation, find min/max entities for  organization
    org_ranges = df.groupby(['prefix', 'organisation']).agg({
        'min_entity': 'min',
        'max_entity': 'max'
    }).reset_index()

    # Calculate  total possible spaces in the range
    org_ranges = org_ranges.sort_values('min_entity')
    org_ranges['range_span'] = org_ranges['max_entity'] - org_ranges['min_entity'] + 1
    
    return org_ranges


entity_ranges = pd.read_csv('entity_ranges_pandas_approach.csv')

final_org_ranges = find_organization_entity_ranges(entity_ranges)


lookup_df = pd.read_csv('lookup.csv')

# Count  actual filled entities by prefix and organisation
filled_counts = lookup_df.groupby(['prefix', 'organisation']).size().reset_index(name='filled_spaces')

#  filled_spaces into final_org_ranges
final_org_ranges = final_org_ranges.merge(filled_counts, on=['prefix', 'organisation'], how='left')

#  NaN  'filled_spaces' with 0, where no filled entries in lookup 
final_org_ranges['filled_spaces'] = final_org_ranges['filled_spaces'].fillna(0).astype(int)

final_org_ranges.rename(columns={"prefix":"dataset", "min_entity": "entity-minimum", "max_entity": "entity-maximum"}, inplace=True)

final_org_ranges = final_org_ranges[["dataset","entity-minimum", "entity-maximum", "organisation"]]
print("Organization Entity Ranges with Filled Spaces:")
print("-" * 50)
for _, row in final_org_ranges.iterrows():
    print(f"Organisation: {row['organisation']}")
    print(f"First Entity: {row['entity-minimum']}")
    print(f"Last Entity:  {row['entity-maximum']}")
    # print(f"Possible Spaces: {row['range_span']}")
    # print(f"Filled Spaces: {row['filled_spaces']}")
    print("-" * 50)


final_org_ranges.to_csv('entity-organisation.csv', index=False)

final_org_ranges
# Out:
# Organization Entity Ranges with Filled Spaces:
# --------------------------------------------------
# Organisation: government-organisation:D1342
# First Entity: 4210000
# Last Entity:  4210003
# --------------------------------------------------
# Organisation: local-authority:SAL
# First Entity: 6300000
# Last Entity:  6300044
# --------------------------------------------------
# Organisation: local-authority:NLN
# First Entity: 6300045
# Last Entity:  6300061
# --------------------------------------------------
# Organisation: local-authority:ROS
# First Entity: 6300062
# Last Entity:  6300095
# --------------------------------------------------
# Organisation: local-authority:CMD
# First Entity: 6300096
# Last Entity:  6300157
# --------------------------------------------------
# Organisation: local-authority:PTE
# First Entity: 6300158
# Last Entity:  6300213
# --------------------------------------------------
# Organisation: local-authority:ROH
# First Entity: 6300214
# Last Entity:  6300229
# --------------------------------------------------
# Organisation: local-authority:CAS
# First Entity: 6300230
# Last Entity:  6300231
# --------------------------------------------------
# Organisation: government-organisation:D1342
# First Entity: 6300232
# Last Entity:  6303117
# --------------------------------------------------
# Organisation: local-authority:BIR
# First Entity: 6300438
# Last Entity:  6300479
# --------------------------------------------------
# Organisation: local-authority:BST
# First Entity: 6300480
# Last Entity:  6300513
# --------------------------------------------------
# Organisation: local-authority:WRL
# First Entity: 6303118
# Last Entity:  6303261
# --------------------------------------------------
# Organisation: local-authority:BNE
# First Entity: 6303262
# Last Entity:  6303301
# --------------------------------------------------
# Organisation: local-authority:PLY
# First Entity: 6303302
# Last Entity:  6303316
# --------------------------------------------------
# Organisation: local-authority:SAL
# First Entity: 44000001
# Last Entity:  44010124
# --------------------------------------------------
# Organisation: government-organisation:PB1164
# First Entity: 44000001
# Last Entity:  44009885
# --------------------------------------------------
# Organisation: local-authority:BRT
# First Entity: 44000071
# Last Entity:  44007977
# --------------------------------------------------
# Organisation: national-park-authority:Q72617988
# First Entity: 44000191
# Last Entity:  44007439
# --------------------------------------------------
# Organisation: local-authority:CON
# First Entity: 44000193
# Last Entity:  44009597
# --------------------------------------------------
# Organisation: local-authority:HAL
# First Entity: 44000380
# Last Entity:  44007963
# --------------------------------------------------
# Organisation: local-authority:NET
# First Entity: 44000537
# Last Entity:  44002959
# --------------------------------------------------
# Organisation: local-authority:OLD
# First Entity: 44000549
# Last Entity:  44012329
# --------------------------------------------------
# Organisation: local-authority:LBH
# First Entity: 44000550
# Last Entity:  44012345
# --------------------------------------------------
# Organisation: local-authority:RDB
# First Entity: 44000591
# Last Entity:  44009051
# --------------------------------------------------
# Organisation: local-authority:WRL
# First Entity: 44000663
# Last Entity:  44012276
# --------------------------------------------------
# Organisation: local-authority:TEW
# First Entity: 44000701
# Last Entity:  44005233
# --------------------------------------------------
# Organisation: local-authority:WBK
# First Entity: 44000713
# Last Entity:  44010140
# --------------------------------------------------
# Organisation: local-authority:CAR
# First Entity: 44000997
# Last Entity:  44009145
# --------------------------------------------------
# Organisation: local-authority:CRY
# First Entity: 44001014
# Last Entity:  44008883
# --------------------------------------------------
# Organisation: local-authority:WND
# First Entity: 44001043
# Last Entity:  44009103
# --------------------------------------------------
# Organisation: local-authority:PTE
# First Entity: 44001130
# Last Entity:  44005183
# --------------------------------------------------
# Organisation: local-authority:NLN
# First Entity: 44001414
# Last Entity:  44005181
# --------------------------------------------------
# Organisation: local-authority:SOS
# First Entity: 44001617
# Last Entity:  44007973
# --------------------------------------------------
# Organisation: local-authority:MAL
# First Entity: 44001675
# Last Entity:  44007830
# --------------------------------------------------
# Organisation: local-authority:GED
# First Entity: 44001676
# Last Entity:  44006734
# --------------------------------------------------
# Organisation: local-authority:EPS
# First Entity: 44001788
# Last Entity:  44009884
# --------------------------------------------------
# Organisation: local-authority:CAT
# First Entity: 44001792
# Last Entity:  44010079
# --------------------------------------------------
# Organisation: local-authority:BRC
# First Entity: 44001799
# Last Entity:  44007965
# --------------------------------------------------
# Organisation: local-authority:MOL
# First Entity: 44001802
# Last Entity:  44008707
# --------------------------------------------------
# Organisation: local-authority:WOX
# First Entity: 44001831
# Last Entity:  44012336
# --------------------------------------------------
# Organisation: local-authority:WAE
# First Entity: 44001859
# Last Entity:  44008655
# --------------------------------------------------
# Organisation: local-authority:STH
# First Entity: 44001995
# Last Entity:  44008198
# --------------------------------------------------
# Organisation: local-authority:EAL
# First Entity: 44002323
# Last Entity:  44008920
# --------------------------------------------------
# Organisation: local-authority:SWK
# First Entity: 44002349
# Last Entity:  44010269
# --------------------------------------------------
# Organisation: local-authority:KTT
# First Entity: 44002387
# Last Entity:  44009068
# --------------------------------------------------
# Organisation: local-authority:BNE
# First Entity: 44002411
# Last Entity:  44006529
# --------------------------------------------------
# Organisation: local-authority:GLA
# First Entity: 44002411
# Last Entity:  44006529
# --------------------------------------------------
# Organisation: local-authority:HIL
# First Entity: 44002425
# Last Entity:  44009093
# --------------------------------------------------
# Organisation: local-authority:RIC
# First Entity: 44002450
# Last Entity:  44009087
# --------------------------------------------------
# Organisation: local-authority:LND
# First Entity: 44002494
# Last Entity:  44012304
# --------------------------------------------------
# Organisation: local-authority:BEX
# First Entity: 44002792
# Last Entity:  44009013
# --------------------------------------------------
# Organisation: local-authority:BRY
# First Entity: 44002813
# Last Entity:  44009101
# --------------------------------------------------
# Organisation: local-authority:WSM
# First Entity: 44002850
# Last Entity:  44009069
# --------------------------------------------------
# Organisation: local-authority:HAV
# First Entity: 44002904
# Last Entity:  44002914
# --------------------------------------------------
# Organisation: local-authority:BDG
# First Entity: 44002915
# Last Entity:  44002918
# --------------------------------------------------
# Organisation: local-authority:CLD
# First Entity: 44003007
# Last Entity:  44007924
# --------------------------------------------------
# Organisation: local-authority:COT
# First Entity: 44003142
# Last Entity:  44007975
# --------------------------------------------------
# Organisation: local-authority:SEG
# First Entity: 44003388
# Last Entity:  44007872
# --------------------------------------------------
# Organisation: local-authority:HNS
# First Entity: 44003402
# Last Entity:  44009075
# --------------------------------------------------
# Organisation: local-authority:NWM
# First Entity: 44003415
# Last Entity:  44003421
# --------------------------------------------------
# Organisation: development-corporation:Q6670544
# First Entity: 44003422
# Last Entity:  44009061
# --------------------------------------------------
# Organisation: local-authority:WFT
# First Entity: 44003424
# Last Entity:  44008877
# --------------------------------------------------
# Organisation: local-authority:TWH
# First Entity: 44003435
# Last Entity:  44010588
# --------------------------------------------------
# Organisation: local-authority:HOR
# First Entity: 44003564
# Last Entity:  44010308
# --------------------------------------------------
# Organisation: local-authority:NED
# First Entity: 44003647
# Last Entity:  44008600
# --------------------------------------------------
# Organisation: local-authority:SLF
# First Entity: 44004019
# Last Entity:  44008711
# --------------------------------------------------
# Organisation: local-authority:SOX
# First Entity: 44004350
# Last Entity:  44009141
# --------------------------------------------------
# Organisation: local-authority:VAL
# First Entity: 44004423
# Last Entity:  44009161
# --------------------------------------------------
# Organisation: local-authority:SHN
# First Entity: 44004834
# Last Entity:  44007679
# --------------------------------------------------
# Organisation: local-authority:SKP
# First Entity: 44004838
# Last Entity:  44004874
# --------------------------------------------------
# Organisation: local-authority:BRD
# First Entity: 44004967
# Last Entity:  44005025
# --------------------------------------------------
# Organisation: local-authority:YOR
# First Entity: 44005080
# Last Entity:  44009138
# --------------------------------------------------
# Organisation: local-authority:MRT
# First Entity: 44005395
# Last Entity:  44009014
# --------------------------------------------------
# Organisation: local-authority:BAB
# First Entity: 44005968
# Last Entity:  44008684
# --------------------------------------------------
# Organisation: local-authority:HCK
# First Entity: 44006227
# Last Entity:  44009089
# --------------------------------------------------
# Organisation: local-authority:BUC
# First Entity: 44006432
# Last Entity:  44010585
# --------------------------------------------------
# Organisation: local-authority:LCE
# First Entity: 44006443
# Last Entity:  44010271
# --------------------------------------------------
# Organisation: local-authority:TRF
# First Entity: 44006481
# Last Entity:  44010414
# --------------------------------------------------
# Organisation: local-authority:SHF
# First Entity: 44006554
# Last Entity:  44009159
# --------------------------------------------------
# Organisation: local-authority:KWL
# First Entity: 44007851
# Last Entity:  44007865
# --------------------------------------------------
# Organisation: local-authority:WNM
# First Entity: 44007873
# Last Entity:  44007873
# --------------------------------------------------
# Organisation: local-authority:ESK
# First Entity: 44007891
# Last Entity:  44007901
# --------------------------------------------------
# Organisation: local-authority:NOW
# First Entity: 44007902
# Last Entity:  44007918
# --------------------------------------------------
# Organisation: local-authority:PUR
# First Entity: 44007978
# Last Entity:  44008103
# --------------------------------------------------
# Organisation: local-authority:DUR
# First Entity: 44008104
# Last Entity:  44008196
# --------------------------------------------------
# Organisation: local-authority:DUD
# First Entity: 44008197
# Last Entity:  44008246
# --------------------------------------------------
# Organisation: local-authority:ROC
# First Entity: 44008337
# Last Entity:  44008346
# --------------------------------------------------
# Organisation: local-authority:HMF
# First Entity: 44008347
# Last Entity:  44012344
# --------------------------------------------------
# Organisation: local-authority:KEC
# First Entity: 44008380
# Last Entity:  44008967
# --------------------------------------------------
# Organisation: local-authority:NDO
# First Entity: 44008601
# Last Entity:  44012343
# --------------------------------------------------
# Organisation: local-authority:ISL
# First Entity: 44008712
# Last Entity:  44009007
# --------------------------------------------------
# Organisation: local-authority:LEW
# First Entity: 44008713
# Last Entity:  44009097
# --------------------------------------------------
# Organisation: local-authority:ENF
# First Entity: 44008714
# Last Entity:  44010295
# --------------------------------------------------
# Organisation: local-authority:HRY
# First Entity: 44008721
# Last Entity:  44009091
# --------------------------------------------------
# Organisation: local-authority:BEN
# First Entity: 44008733
# Last Entity:  44008910
# --------------------------------------------------
# Organisation: local-authority:HRW
# First Entity: 44008756
# Last Entity:  44009102
# --------------------------------------------------
# Organisation: local-authority:STN
# First Entity: 44008764
# Last Entity:  44008872
# --------------------------------------------------
# Organisation: local-authority:GRE
# First Entity: 44008815
# Last Entity:  44009056
# --------------------------------------------------
# Organisation: local-authority:CHI
# First Entity: 44009104
# Last Entity:  44009107
# --------------------------------------------------
# Organisation: local-authority:BOL
# First Entity: 44009108
# Last Entity:  44012320
# --------------------------------------------------
# Organisation: local-authority:CMD
# First Entity: 44009614
# Last Entity:  44009885
# --------------------------------------------------
# Organisation: local-authority:GLO
# First Entity: 44009664
# Last Entity:  44009677
# --------------------------------------------------
# Organisation: local-authority:GRY
# First Entity: 44009678
# Last Entity:  44009700
# --------------------------------------------------
# Organisation: local-authority:DOV
# First Entity: 44009701
# Last Entity:  44009803
# --------------------------------------------------
# Organisation: local-authority:MDW
# First Entity: 44009804
# Last Entity:  44009827
# --------------------------------------------------
# Organisation: local-authority:BIR
# First Entity: 44009828
# Last Entity:  44009856
# --------------------------------------------------
# Organisation: local-authority:GAT
# First Entity: 44009857
# Last Entity:  44010270
# --------------------------------------------------
# Organisation: local-authority:DNC
# First Entity: 44009886
# Last Entity:  44009931
# --------------------------------------------------
# Organisation: local-authority:ROS
# First Entity: 44010125
# Last Entity:  44010134
# --------------------------------------------------
# Organisation: local-authority:NSM
# First Entity: 44010141
# Last Entity:  44010179
# --------------------------------------------------
# Organisation: local-authority:ECA
# First Entity: 44010180
# Last Entity:  44010207
# --------------------------------------------------
# Organisation: local-authority:SAW
# First Entity: 44010208
# Last Entity:  44010216
# --------------------------------------------------
# Organisation: local-authority:ROH
# First Entity: 44010296
# Last Entity:  44010305
# --------------------------------------------------
# Organisation: local-authority:CAS
# First Entity: 44010309
# Last Entity:  44010310
# --------------------------------------------------
# Organisation: government-organisation:D1342
# First Entity: 44010311
# Last Entity:  44012250
# --------------------------------------------------
# Organisation: local-authority:BST
# First Entity: 44010589
# Last Entity:  44010622
# --------------------------------------------------
# Organisation: local-authority:PLY
# First Entity: 44012305
# Last Entity:  44012319
# --------------------------------------------------
#                              dataset  entity-minimum  entity-maximum  \
# 0    conservation-area-document-type         4210000         4210003
# 1         conservation-area-document         6300000         6300044
# 2         conservation-area-document         6300045         6300061
# 3         conservation-area-document         6300062         6300095
# 4         conservation-area-document         6300096         6300157
# ..                               ...             ...             ...
# 112                conservation-area        44010296        44010305
# 113                conservation-area        44010309        44010310
# 114                conservation-area        44010311        44012250
# 115                conservation-area        44010589        44010622
# 116                conservation-area        44012305        44012319
#
#                       organisation
# 0    government-organisation:D1342
# 1              local-authority:SAL
# 2              local-authority:NLN
# 3              local-authority:ROS
# 4              local-authority:CMD
# ..                             ...
# 112            local-authority:ROH
# 113            local-authority:CAS
# 114  government-organisation:D1342
# 115            local-authority:BST
# 116            local-authority:PLY
#
# [117 rows x 4 columns]

# %%
df = pd.read_csv('entity-organisation.csv')  

# Ensure numeric  entities
df['entity-minimum'] = pd.to_numeric(df['entity-minimum'], errors='coerce')
df['entity-maximum'] = pd.to_numeric(df['entity-maximum'], errors='coerce')

overlapping_ranges = []

# Compare each row with every other row
for i in range(len(df)):
    for j in range(i+1, len(df)):
        #  organisations are different to avoid comparing same 
        if df.loc[i, 'organisation'] != df.loc[j, 'organisation']:
            # Check  overlap
            overlap = not (
                df.loc[i, 'entity-maximum'] < df.loc[j, 'entity-minimum'] or 
                df.loc[i, 'entity-minimum'] > df.loc[j, 'entity-maximum']
            )
            
            if overlap:
                overlap_info = {
                    'Dataset 1': df.loc[i, 'dataset'],
                    'Organisation 1': df.loc[i, 'organisation'],
                    'Entity Min 1': df.loc[i, 'entity-minimum'],
                    'Entity Max 1': df.loc[i, 'entity-maximum'],
                    'Dataset 2': df.loc[j, 'dataset'],
                    'Organisation 2': df.loc[j, 'organisation'],
                    'Entity Min 2': df.loc[j, 'entity-minimum'],
                    'Entity Max 2': df.loc[j, 'entity-maximum']
                }
                overlapping_ranges.append(overlap_info)

overlap_df = pd.DataFrame(overlapping_ranges)
overlap_df.to_csv('entity-organisation-overlap.csv', index=False)
print("Total Overlapping Ranges:", len(overlap_df))
display(overlap_df)

# by organisation
print("\nOverlaps by Organisation:")
overlap_summary = overlap_df.groupby(['Organisation 1', 'Organisation 2']).size().reset_index(name='Overlap Count')
display(overlap_summary)
# Out:
# Total Overlapping Ranges: 3123
#                        Dataset 1                 Organisation 1  Entity Min 1  \
# 0     conservation-area-document  government-organisation:D1342       6300232
# 1     conservation-area-document  government-organisation:D1342       6300232
# 2              conservation-area            local-authority:SAL      44000001
# 3              conservation-area            local-authority:SAL      44000001
# 4              conservation-area            local-authority:SAL      44000001
# ...                          ...                            ...           ...
# 3118           conservation-area            local-authority:GAT      44009857
# 3119           conservation-area            local-authority:GAT      44009857
# 3120           conservation-area            local-authority:GAT      44009857
# 3121           conservation-area            local-authority:GAT      44009857
# 3122           conservation-area  government-organisation:D1342      44010311
#
#       Entity Max 1                   Dataset 2  \
# 0          6303117  conservation-area-document
# 1          6303117  conservation-area-document
# 2         44010124           conservation-area
# 3         44010124           conservation-area
# 4         44010124           conservation-area
# ...            ...                         ...
# 3118      44010270           conservation-area
# 3119      44010270           conservation-area
# 3120      44010270           conservation-area
# 3121      44010270           conservation-area
# 3122      44012250           conservation-area
#
#                          Organisation 2  Entity Min 2  Entity Max 2
# 0                   local-authority:BIR       6300438       6300479
# 1                   local-authority:BST       6300480       6300513
# 2        government-organisation:PB1164      44000001      44009885
# 3                   local-authority:BRT      44000071      44007977
# 4     national-park-authority:Q72617988      44000191      44007439
# ...                                 ...           ...           ...
# 3118                local-authority:ROS      44010125      44010134
# 3119                local-authority:NSM      44010141      44010179
# 3120                local-authority:ECA      44010180      44010207
# 3121                local-authority:SAW      44010208      44010216
# 3122                local-authority:BST      44010589      44010622
#
# [3123 rows x 8 columns]
# Overlaps by Organisation:
#                          Organisation 1       Organisation 2  Overlap Count
# 0      development-corporation:Q6670544  local-authority:BAB              1
# 1      development-corporation:Q6670544  local-authority:BEN              1
# 2      development-corporation:Q6670544  local-authority:BRD              1
# 3      development-corporation:Q6670544  local-authority:BUC              1
# 4      development-corporation:Q6670544  local-authority:DUD              1
# ...                                 ...                  ...            ...
# 3117  national-park-authority:Q72617988  local-authority:WND              1
# 3118  national-park-authority:Q72617988  local-authority:WOX              1
# 3119  national-park-authority:Q72617988  local-authority:WRL              1
# 3120  national-park-authority:Q72617988  local-authority:WSM              1
# 3121  national-park-authority:Q72617988  local-authority:YOR              1
#
# [3122 rows x 3 columns]
