# %% [markdown]
# # Analysis: green-belt data changes
# **Author**:  Greg Slater <br>
# **Date**:  15 May 2024 <br>
# **Data Scope**: green-belt<br>
# **Report Type**: One off analysis <br>
#
# ## Purpose
# This notebook was used to get a list of all historic green-belt endpoints and resources, as well as download historic cached resources in order to compare what resources have been end-dated (410'd) with which resources are returning valid data.
#
# A number of historic green-belt resources were retired: https://github.com/digital-land/config/tree/main/collection/green-belt. But also, resource history shows there was a change which looks like historic endpoints stopped working and instead returned a WFS service error message. This still gives a 200 status even though it's invalid data, hence downloading resources to check what's what and what can be un-end-dated.

# %%
import pandas as pd
import geopandas as gpd
import os
import numpy as np
import urllib

# %%
def get_greenbelt_resources():
    datasette_url = "https://datasette.planning.data.gov.uk/"
  
    params = urllib.parse.urlencode({
    "sql": f"""
    select 
        endpoint, endpoint_url, status, resource, count(distinct resource) as count_res, STRFTIME("%Y-%m-%d", max(latest_log_entry_date)) as max_log, max(resource_end_date) as max_res_end
        from reporting_historic_endpoints
        where pipeline = "green-belt"
        group by 1, 2, 3, 4
        order by endpoint, max(latest_log_entry_date) desc
    """,
    "_size": "max"
    })
    
    url = f"{datasette_url}digital-land.csv?{params}"
    df = pd.read_csv(url)
    return df


def get_resource_file(collection_name, resource_id):

    url = f"https://files.planning.data.gov.uk/{collection_name}-collection/collection/resource/{resource_id}"

    try:
        gdf = gpd.read_file(url)

    # except urllib.error.HTTPError:
    #     print(f"can't read url: {url}")
    #     return None
    
    except:
        print(f"Error reading from url: {url}")
        return None

    return gdf

# %%
test = get_resource_file("green-belt", "54ff74f45e458c4e7d139689de57a8b7e7d768d9c1ccb11a0026903093842341")

print(len(test))
test.head()
# Out:
# 185
#                              gml_id                LAD_NM     LAD_CD  \
# 0  England_Green_Belt_2022_23_WGS84          Amber Valley  E07000032
# 1  England_Green_Belt_2022_23_WGS84              Ashfield  E07000170
# 2  England_Green_Belt_2022_23_WGS84  Barking and Dagenham  E09000002
# 3  England_Green_Belt_2022_23_WGS84                Barnet  E09000003
# 4  England_Green_Belt_2022_23_WGS84              Barnsley  E08000016
#
#                     GB_Name       Area_ha  \
# 0      Derby and Nottingham   8647.904471
# 1      Derby and Nottingham   4521.598181
# 2                    London    527.776471
# 3                    London   2383.047837
# 4  South and West Yorkshire  22393.050084
#
#                                             geometry
# 0  MULTIPOLYGON (((-1.34303 53.07100, -1.34304 53...
# 1  MULTIPOLYGON (((-1.18089 53.11499, -1.18089 53...
# 2  MULTIPOLYGON (((0.15314 51.56697, 0.15325 51.5...
# 3  MULTIPOLYGON (((-0.20927 51.63758, -0.20937 51...
# 4  MULTIPOLYGON (((-1.27572 53.52946, -1.27574 53...

# %%
# global variables
data_dir = "../data/geo_analysis/green_belt/"
os.makedirs(data_dir, exist_ok=True)

# %% [markdown]
# ## Analysis

# %%
# get list of endpoints and historic resources from datasette 
gb_df = get_greenbelt_resources()

# get year from URL part
gb_df["year"] = gb_df["endpoint_url"].str.split("&").apply(lambda x: x[3][-13:-6])

print(len(gb_df))
gb_df.sort_values(["year", "max_log"], inplace=True, ascending= False)
gb_df.head(50)
# Out:
# 46
#                                              endpoint  \
# 0   0a348ac5a298612f216088f285ab4fd049752bd663f058...
http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 31  http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 32  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 33  http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 34  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 6   http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 7   http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 8   http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 9   http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 10  http://maps.communities.gov.uk/geoserver/dclg_...   500.0
# 11  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 35  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 36  http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 37  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 38  http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 39  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 23  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 24  http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 25  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 26  http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 27  http://maps.communities.gov.uk/geoserver/dclg_...     NaN
# 28  http://maps.communities.gov.uk/geoserver/dclg_...   500.0
# 29  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 40  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 41  http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 42  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 43  http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 44  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 12  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 13  http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 14  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 15  http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 16  http://maps.communities.gov.uk/geoserver/dclg_...     NaN
# 17  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 1   http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 2   http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 3   http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 4   http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 5   http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 18  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 19  http://maps.communities.gov.uk/geoserver/dclg_...   520.0
# 20  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
# 21  http://maps.communities.gov.uk/geoserver/dclg_...   524.0
# 22  http://maps.communities.gov.uk/geoserver/dclg_...   200.0
#
#                                              resource  count_res     max_log  \
# 0   54ff74f45e458c4e7d139689de57a8b7e7d768d9c1ccb1...          1  2024-05-16
# 45  232a469fec0b0af41a628e1cc5203749af3c165156cb8e...          1  2024-05-16
# 30  f3ec886559271bd6fe0e6650dee5e8928593146ea78102...          1  2024-05-16
# 31                                                NaN          1  2024-02-02
# 32  2858fa51c91289f4ad90ee2e600aa7a586cac68884affc...          1  2023-11-27
# 33                                                NaN          1  2023-11-03
# 34  f413faf9e8f7e38a38d94003b5248f827cd3dd74218de3...          1  2022-10-06
# 6   f70c012718b6a8dbd9ac6e92dd54e3a49378e21362bf44...          1  2024-05-16
# 7                                                 NaN          1  2024-02-02
# 8   ebf46d50cde4bdd1fec04890e12eebc7158983ab24a7bf...          1  2023-11-27
# 9                                                 NaN          1  2023-11-03
# 10                                                NaN          1  2023-01-06
# 11  c8d32155174262eec375bcbac5b2c89ed43e27a8946f99...          1  2021-11-21
# 35  3e4a14df5e220a545561d8dffabc5de7481d896f9f0e05...          1  2024-05-16
# 36                                                NaN          1  2024-02-02
# 37  c664927a77fa482d9671464599f0c007218793db3bb68b...          1  2023-11-27
# 38                                                NaN          1  2023-11-03
# 39  6f74ea15b5cd53bc752d23a6d5a1f25388bd330c9c7617...          1  2021-11-21
# 23  5254b381408f674c53aa20d4af8d517c6afbde7a45441b...          1  2024-05-16
# 24                                                NaN          1  2024-02-02
# 25  0e2cc42c6fcd06aebb3717e9a13cefbaa5a3c6590ba044...          1  2023-11-27
# 26                                                NaN          1  2023-11-03
# 27                                                NaN          1  2023-03-03
# 28                                                NaN          1  2023-01-07
# 29  983d409a0aedfa6efe9d8ba0a66d154566fe1ab826e4f0...          1  2021-11-21
# 40  ce01675696c982c4ce258c0be5d2ecfbf1322331dc5d55...          1  2024-05-16
# 41                                                NaN          1  2024-02-02
# 42  78d688e8977bcfeb00ce80679b2443b836b1ae275d87c6...          1  2023-11-27
# 43                                                NaN          1  2023-11-03
# 44  111622fd0f0d9dd506764bdc361b45d2f7fb1c7a7297e2...          1  2021-11-21
# 12  f22b92f7b52bf24c17d79ac6dfaa303d1bdd6395aebb99...          1  2024-05-16
# 13                                                NaN          1  2024-02-02
# 14  bcc3680ca22f1e011cf1e1484d62f86f9ddf5d6ebfbd15...          1  2023-11-27
# 15                                                NaN          1  2023-11-03
# 16                                                NaN          1  2022-11-09
# 17  d7f1e9256d7001793b0f7004fa741e205f988ad24a1d60...          1  2021-11-21
# 1   e2b858e90b62e8c66d023ddbb510fac5676d58dd0a19b5...          1  2024-05-16
# 2                                                 NaN          1  2024-02-02
# 3   7f9b19c1c5b08e6619b164ef2e18812a8199ae150e8303...          1  2023-11-27
# 4                                                 NaN          1  2023-11-03
# 5   5d462aa86f638be20e7fe0d531434f3bf10761dee2dbcf...          1  2021-11-21
# 18  297a1344930a0c63e086c0a565d16beef6f240f5704da1...          1  2024-05-16
# 19                                                NaN          1  2024-02-02
# 20  f099d2b394eae7a6f0c12957ec55324a01346dd87d914c...          1  2023-11-27
# 21                                                NaN          1  2023-11-03
# 22  26dfbfa718b56dbf76a8d2182859371073a63332600a88...          1  2021-11-21
#
#    max_res_end     year
# 0          NaN  2022_23
# 45         NaN  2021_22
# 30         NaN  2020-21
# 31         NaN  2020-21
# 32  2023-11-27  2020-21
# 33         NaN  2020-21
# 34  2022-10-06  2020-21
# 6          NaN  2019-20
# 7          NaN  2019-20
# 8   2023-11-27  2019-20
# 9          NaN  2019-20
# 10         NaN  2019-20
# 11  2021-11-21  2019-20
# 35         NaN  2018-19
# 36         NaN  2018-19
# 37  2023-11-27  2018-19
# 38         NaN  2018-19
# 39  2021-11-21  2018-19
# 23         NaN  2017-18
# 24         NaN  2017-18
# 25  2023-11-27  2017-18
# 26         NaN  2017-18
# 27         NaN  2017-18
# 28         NaN  2017-18
# 29  2021-11-21  2017-18
# 40         NaN  2016-17
# 41         NaN  2016-17
# 42  2023-11-27  2016-17
# 43         NaN  2016-17
# 44  2021-11-21  2016-17
# 12         NaN  2015-16
# 13         NaN  2015-16
# 14  2023-11-27  2015-16
# 15         NaN  2015-16
# 16         NaN  2015-16
# 17  2021-11-21  2015-16
# 1          NaN  2014-15
# 2          NaN  2014-15
# 3   2023-11-27  2014-15
# 4          NaN  2014-15
# 5   2021-11-21  2014-15
# 18         NaN  2013-14
# 19         NaN  2013-14
# 20  2023-11-27  2013-14
# 21         NaN  2013-14
# 22  2021-11-21  2013-14

# %%
# get resources which have been 410'd
old_res_df = pd.read_csv("https://raw.githubusercontent.com/digital-land/config/main/collection/green-belt/old-resource.csv")

old_res_df.head()
# Out:
#                                         old-resource  status  resource  \
# 0  0e2cc42c6fcd06aebb3717e9a13cefbaa5a3c6590ba044...     410       NaN
# 1  111622fd0f0d9dd506764bdc361b45d2f7fb1c7a7297e2...     410       NaN
# 2  26dfbfa718b56dbf76a8d2182859371073a63332600a88...     410       NaN
# 3  5d462aa86f638be20e7fe0d531434f3bf10761dee2dbcf...     410       NaN
# 4  6f74ea15b5cd53bc752d23a6d5a1f25388bd330c9c7617...     410       NaN
#
#                notes
# 0  paused processing
# 1  paused processing
# 2  paused processing
# 3  paused processing
# 4  paused processing

# %%
# join 410 status on to the endpoint-resource list
gb_res_df = gb_df.merge(
    old_res_df[["old-resource", "status"]],
    how = "left",
    left_on = "resource",
    right_on = "old-resource",
    suffixes=["_endpoint", "_resource"]
)

# save a list of 200 endpoints and their resources - will use to check off what should be un-ended and what should be ended.
gb_res_df[gb_res_df["status_endpoint"] == 200][
    ["year", "endpoint", "status_endpoint", "resource", "max_log", "max_res_end", "status_resource"]
    ].to_csv("temp-green_belt-endpoint_resource2.csv", index = False)

# %%
# save historic resources to check if valid or not - will manually check through and flag using csv list saved above.

res_unique = gb_df[gb_df["resource"].notnull()]["resource"].drop_duplicates()
url_base = "https://files.planning.data.gov.uk/green-belt-collection/collection/resource/"

# save each resource in data directory
for r in res_unique:

    url = url_base + r
    f_path = f"{data_dir}{r}.xml"
    print(f"Retrieving: {f_path}")
    urllib.request.urlretrieve(url, f_path)
    print("Done")
    print("-" * 50)
# Out:
# Retrieving: ../data/geo_analysis/green_belt/ce01675696c982c4ce258c0be5d2ecfbf1322331dc5d55fe42c076e767698cfa.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/78d688e8977bcfeb00ce80679b2443b836b1ae275d87c6c0b8254a54f941efb1.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/111622fd0f0d9dd506764bdc361b45d2f7fb1c7a7297e2310109d662020a26b7.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/f22b92f7b52bf24c17d79ac6dfaa303d1bdd6395aebb99190e7d8e8e332d9036.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/bcc3680ca22f1e011cf1e1484d62f86f9ddf5d6ebfbd15d2c6a770f56b454440.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/d7f1e9256d7001793b0f7004fa741e205f988ad24a1d60cc28970f8334a355a5.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/e2b858e90b62e8c66d023ddbb510fac5676d58dd0a19b566f5bd4be174f474b7.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/7f9b19c1c5b08e6619b164ef2e18812a8199ae150e8303072a41df89e1954022.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/5d462aa86f638be20e7fe0d531434f3bf10761dee2dbcf8b5c7e11532f8fc7d1.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/297a1344930a0c63e086c0a565d16beef6f240f5704da16866f399265d7b86f8.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/f099d2b394eae7a6f0c12957ec55324a01346dd87d914c4b4b61aeb4206ea82d.xml
# Done
# --------------------------------------------------
# Retrieving: ../data/geo_analysis/green_belt/26dfbfa718b56dbf76a8d2182859371073a63332600a8860c8bd84fcc09cbbe1.xml
# Done
# --------------------------------------------------
